# %% [markdown]
# # Introduction to Data Science – Lecture 12 – Web Scraping
# *COMP 5360 / MATH 4100, University of Utah, http://datasciencecourse.net/*
#
# In this lecture we will explore how we can extract data from a web-page using automatic scraping and crawling with [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# First, we'll talk a bit about HTML though.

# %% [markdown]
# ## HTML and the DOM
#
# We will scrape web-pages that are (partially) written in HTML and represented in the DOM. DOM stands for  Document Object Model, while HTML stands for “HyperText Markup Language”. 25 years ago, that used to be a meaningful description of what HTML actually did: it has links (hypertext), and it is a markup language. The latest version of HTML, however, the HTML5 standard, does much, much more: graphics, audio, video, etc. So it is easier to think of HTML as “whatever it is that web browsers know how to interpret”, and just not think about the actual term.

# %% [markdown]
# ### Elements
#
# The important thing about HTML is that the markup is represented by elements. An HTML element is a portion of the content that is surrounded by a pair of tags of the same name. Like this:
#
# ```html
# <strong>This is an HTML element.</strong>
# ```
#
# In this element, strong is the name of the tag; the open tag is `<strong>`, and the matching closing tag is `</strong>`. The way you should interpret this is that the text “This is an HTML element” should be “strong”, i.e., typically this will be bold text.
#
# HTML elements can and commonly do nest:
#
# ```html
# <strong>This is strong, and <u>this is underlined and strong.</u></strong>
# ```
#
# In addition to the names, opening tags can contain extra information about the element. These are called attributes:
#
# ```html
# <a href='http://www.google.com'>A link to Google's main page</a>
# ```
#
# In this case, we’re using the `a` element which stood for “anchor”, but now is almost universally used as a “link”. The attribute `href` means “HTML reference”, which actually makes sense for a change. The meaning given to each attribute changes from element to element.
#
# Important attributes for our purposes are `id` and `class`. The id attribute gives the attribute a unique identifier, which can then be used to access the element programmatically. Think of it as making the element accessible via a global variable.
#
# The class is conceptually similar but is intendent to be applied to a whole “class” of elements.
#
# HTML pages require some boilerplate. Here is a minimal page:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title></title>
# </head>
# <body>
# Hello World! What's up?
# </body>
# </html>
# ```
#
# The `<head>` contains meta-information such as the titel of the site, the `<body>` contains the actual data.

# %% [markdown]
# ### Hierarchy
#
# Data in HTML is often structured hirearchically:
#
# ```html
# <body>
#   <article>
#     <span class="date">Published: 1969-10-22</span>
#     <span class="author">Led Zeppelin</span>
#     <h1>Ramble On</h1>
#     <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     <div>
#   </article>
#   <article>
#     <span class="date">Published: 2016-05-03</span>
#     <span class="author">Radiohead</span>
#     <h1>Burn the Witch</h1>
#     <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     <div>
#   </article>
# </body>
# ```
#
# Here, the title of the song is nested three levels deep: `body > article > h1`.

# %% [markdown]
# ### Tables
#
# Data is also often stored in HTML tables. `<tr>` indicates a row (table row), `<th>` and `<td>` are used to demark cells, either header cells (`<th>`) or regular cells (`<td>`).
#
# ```html
# <table>
#     <tr>
#         <th></th>
#         <th>The Beatles</th>
#         <th>Led Zeppelin</th>
#     </tr>
#     <tr>
#         <td># Band Members</td>
#         <td>4</td>
#         <td>4</td>
#     </tr>
# </table>
# ```

# %% [markdown]
# ### The DOM
#
# As we have seen above, a markup document looks a lot like a tree: it has a root, the HTML element, and elements can have children that are containing elements themselves.
#
# While HTML is a textual representation of a markup document, the DOM is a programming interface for it. Also the DOM represents the state of a page as it's rendered, that (nowadays) doesn't mean that there is an underlying HTML document that corresponds to that exactly. Rather, the DOM is dynamically generated with, e.g., JavaScript.
#
# In this class we will use “DOM” to mean the tree created by the web browsers to represent the document.
#
# #### Inspecting the DOM in a browser
#
# Perhaps the most important habit when scraping is to investigate the source of a page using the Developer Tools. In this case, we’ll look at the Element tree, by clicking on the menu bar: View → Developer → Developer Tools.
#
# Alternatively, you can right click on any part of the webpage, and choose “Inspect Element”. Notice that there can be a big difference between what is in the DOM and what is in the source.
#
# Take a look at the DOM of [this html page](lyrics.html). Next, we'll scrape the data from this page!

# %% [markdown]
# # Scraping with BeautifulSoup
#
# [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) is a Python library design for computationally extracting data from html documents. It supports navigating in the DOM and retreiving exactly the data elements you need.
#
# Let's start with a simple example using the [lyrics.html](lyrics.html) file.

# %%
from bs4 import BeautifulSoup

# we tell BeautifulSoup and tell it which parser to use
song_soup = BeautifulSoup(open("lyrics.html"), "html.parser")
# the output corresponds exactly to the html file
song_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Lyrics</title>
# </head>
# <body>
# <article id="zep">
# <span class="date">Published: 1969-10-22</span>
# <span class="author">Led Zeppelin</span>
# <h1>Ramble On</h1>
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# </article>
# <article id="radio">
# <span class="date">Published: 2016-05-03</span>
# <span class="author">Radiohead</span>
# <h1>Burn the Witch</h1>
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>
# </article>
# </body>
# </html>

# %%
# sometimes that can be hard to read (not in this case), so we can format it
print(song_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Lyrics
#   </title>
#  </head>
#  <body>
#   <article id="zep">
#    <span class="date">
#     Published: 1969-10-22
#    </span>
#    <span class="author">
#     Led Zeppelin
#    </span>
#    <h1>
#     Ramble On
#    </h1>
#    <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#    </div>
#   </article>
#   <article id="radio">
#    <span class="date">
#     Published: 2016-05-03
#    </span>
#    <span class="author">
#     Radiohead
#    </span>
#    <h1>
#     Burn the Witch
#    </h1>
#    <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#    </div>
#   </article>
#  </body>
# </html>

# %% [markdown]
# We can access content by tags:

# %%
# get the title tag
song_soup.title
# Out:
# <title>Lyrics</title>

# %% [markdown]
# And get the text out of the tag:

# %%
song_soup.title.string
# Out:
# 'Lyrics'

# %% [markdown]
# Directly accessing an element works for the first occurence of a tag, we don't get the others.

# %%
song_soup.div
# Out:
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>

# %% [markdown]
# Again, we can retreive the text content of an element:

# %%
print(song_soup.div.string)
# Out:
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can use attributes to find a specific element:

# %%
song_soup.find(id="zep")
# Out:
# <article id="zep">
# <span class="date">Published: 1969-10-22</span>
# <span class="author">Led Zeppelin</span>
# <h1>Ramble On</h1>
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# </article>

# %% [markdown]
#  We can also get only the text, not the html markup with [`find()`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find):

# %%
text = song_soup.find(id="zep").get_text()
print(text)
# Out:
# Published: 1969-10-22
# Led Zeppelin
# Ramble On
#
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can also use `[find_all()](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#calling-a-tag-is-like-calling-find-all)` to get all instances of a tag:

# %%
h1s = song_soup.find_all("h1")
h1s
# Out:
# [<h1>Ramble On</h1>, <h1>Burn the Witch</h1>]

# %% [markdown]
# This returns a list of beautiful soup elements:

# %%
type(h1s[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# It's easy to get the text out of this:

# %%
string_h1s = [tag.get_text() for tag in h1s]
string_h1s
# Out:
# ['Ramble On', 'Burn the Witch']

# %% [markdown]
# Since `find_all` is so commonly used, you can use a shortcut by just calling directly on an object:

# %%
song_soup("div")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>, <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# We can address the elements in the returned object directly:

# %%
song_soup("div")[1]
# Out:
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# Or iterate over it:

# %%
for p in song_soup.find_all("div"):
    print("---")
    print(p)
# Out:
# ---
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# ---
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# ### CSS Selectors
#
# We can also use CSS selectors. CSS Selectors apply, among others, to elements, classes, and IDs.
#
# Below is an example of how CSS is used to style different elements.
#
#
# ```CSS
# /* Element Selector */
# article {
#   color: FireBrick;
# }
#
# /* ID selector */
# #myID {
#   color: Tomato;
# }
#
# /* Class selector */
# .myClass {
#   color: Aquamarine;
# }
#
# /* Child selector. Only DIRECT children match */
# p > b {
#   color: SteelBlue;
# }
#
# /* Descendant selector. Every time a b is nested within a div this matches */
# div b {
#   color: green;
# }
#
# ```
#
# [Here is an example](https://jsfiddle.net/gxhqv26m/1/) with all the important selectors.
#
# Let's try this in Python:

# %%
# selecting all elements of class .content
song_soup.select(".content")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>, <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %%
# selecting all divs that are somewhere below the id radio in the tree
song_soup.select("#radio div")
# Out:
# [<div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# OK, now we know how to extract information out of a website. Let's look at a complete example.

# %% [markdown]
# ## Fetching a Website
#
# Downloading websites is easy and very efficient. It turns out, that you can cause quite high load on a server when you scrape a lot. So webmasters usually publish what kinds of scraping they allow on their websites. You should check out a websites terms of service and the `robots.txt` of a domain before crawling excessively. Terms of service are usually broad, so searching for “scraping” or “crawling” is a good idea.
#
# Let's take a look at [Google Scholar's robots.txt](https://scholar.google.com/robots.txt):
#
# ```
# User-agent: *
# Disallow: /search
# Allow: /search/about
# Disallow: /sdch
# Disallow: /groups
# Disallow: /index.html?
# Disallow: /?
# Allow: /?hl=
# ...
# Disallow: /scholar
# Disallow: /citations?
# ...
# ```
#
# Here it specifies that you're not allowed to crawl a lot of the pages. The `/scholar` subdirectory is especially painful because it prohibits you from generating queries dynamically.
#
# It's also common that sites ask you to delay crawiling:
#
# ```
# Crawl-delay: 30
# Request-rate: 1/30
# ```
#
# You should respect those restrictions. Now, no one can stop you from running a request through a crawler, but sites like google scholar will block you VERY quickly if you request to many pages in a short time-frame.
#
# An alternative strategy to dynamically accessing the site you're crawling (as we're doing in the next example) is to download a local copy of the website and crawl that. This ensures that you hit the site only once per page. A good tool to achieve that is [wget](https://www.gnu.org/software/wget/).

# %% [markdown]
# ### Example: Utah's course enrollments
#
# We're going to build a dataset of classes offered this fall at the U and look at the enrollment numbers. We'll use the catalog listed here:
# https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/
#
# The U doesn't seem to care whether/how we crawl the websites, the [fineprint](https://www.utah.edu/disclaimer/) doesn't mentione it and there is no `robots.txt`: http://www.utah.edu/robots.txt
#
# We'll use the [`urllib.request`](https://docs.python.org/3.0/library/urllib.request.html) library to retreive the websites.

# %%
import urllib.request
url = "https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/"
# here we actually access the website
with urllib.request.urlopen(url) as response:
    html = response.read()
    html = html.decode('utf-8')

# save the file
with open('class_schedule.html', 'w') as new_file:
    new_file.write(html)

# here it's already a local operation
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Let's take a look at the first 5000 lines of this page:

# %%
print(soup.prettify()[0:5000])
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Class Schedules
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="//templates.utah.edu/apps/v1/_css/main.css" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="/uofu/stu/ClassSchedules/css/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="/uofu/stu/ClassSchedules/images/favicon.ico" rel="icon" type="image/ico"/>
#   <meta content="IE=10; IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>
#   <script src="//templates.utah.edu/apps/v1/_js/vendor/modernizr-2.6.2.min.js">
#   </script>
#   <script src="/uofu/stu/ClassSchedules/scripts/jquery.min.js">
#   </script>
#   <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js">
#   </script>
#   <script src="/uofu/stu/ClassSchedules/scripts/elevator.min.js">
#   </script>
#   <script>
#    $(window).load(function(){
#                 var elevator = new Elevator({
#                     mainAudio: "/uofu/stu/ClassSchedules/resources/bg.mp3",
#                     endAudio: "/uofu/stu/ClassSchedules/resources/ding.mp3"
#                 });
#
#                 $('.elevator-button').on('click', function(e) {
#                     if (e.altKey) {
#                         e.preventDefault();
#                         elevator.elevate();
#                     } else {
#                         $(document).scrollTop(0);
#                     }
#                 });
#             });
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function ()
#                 {
#                     (i[r].q = i[r].q || []).push(arguments)
#                 }
#                 , i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#             ga('create', "UA-58881890-50", 'auto');
#             ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  </head>
#  <body>
#   <header class="uu-header" id="top" role="banner">
#    <div class="uu-container">
#     <a class="skip sr-only focusable" href="#uu-skip-target">
#      Skip to Main Content
#     </a>
#     <div class="row">
#      <!-- header logo 1 -->
#      <div class="col-sm-6">
#       <div class="uu-logo">
#        <a href="http://www.utah.edu/">
#         <img alt="The University of Utah" src="/uofu/stu/ClassSchedules/images/U.png"/>
#        </a>
#       </div>
#       <div class="uu-org-title">
#        <h2>
#         <a href="http://www.utah.edu/">
#          <img src="/uofu/stu/ClassSchedules/images/Ulogo.png"/>
#         </a>
#        </h2>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <nav class="uu-nav navbar navbar-inverse" role="navigation">
#    <div class="uu-container">
#     <a class="uu-nav-link" href="index.html">
#      Home
#     </a>
#    </div>
#   </nav>
#   <div class="uu-breadcrumb">
#    <div class="uu-container">
#     <div class="row">
#      <div class="col-sm-7">
#       <section>
#        <h1>
#         Main Campus
#        </h1>
#        <h5 class="subject-info">
#         Spring 2019 Class Schedule
#        </h5>
#       </section>
#      </div>
#      <div class="col-sm-5">
#       <div class="subject-info">
#        <section>
#        </section>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section>
#    <main class="uu-main class-subject" role="main">
#     <div class="uu-container" id="uu-skip-target">
#      <div class="row">
#       <div class="col-md-10">
#        <table class="table table-bordered table-striped table-responsive">
#         <tr>
#          <th colspan="2">
#           Available U of U Classes
#          </th>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_list.html?listType=GEN">
#            Gen Ed &amp; Bachelor Degree Courses
#           </a>
#          </td>
#          <td>
#           FF, FI, AI, CW, DV, IR, etc.
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_list.html?listType=SESSION">
#            Class Sessions
#           </a>
#          </td>
#          <td>
#           <span>
#            Second, Third and Fourth Session Classes
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_index.html?type=AOCE">
#            Continuing Education Classes
#           </a>
#          </td>
#          <td>
#           Continuing Education Credit and Non-Credit Classes
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_index.html?type=FLXU">
#            Flexible Classes
#           </a>
#          </td>
#          <td

# %% [markdown]
# What we want to get out of this page is the link to the subject specific subject course lists.
#
# While you could find this in the text output in python, it's much easier to find the relevant parts in your browser's built in inspector. Here, we've highlighted one of the subjects (Anesthesiology):
#
# ![Chrome Inspector](inspector.png)

# %% [markdown]
# This is the relevant HTML snippet:
#
# ```html
# <ul class="subject-list">
#   <li class="row"><a class="col-sm-4" href="class_list.html?subject=ANES">ANES</a><span class="col-md-10">Anesthesiology</span></li>
# </ul>
# ```
#
# We can scrape this based on the "subject-list" class attribute.
#
# Let's build a dictionary of subject shorthands to a tuple of the full subject name and links to the relevant courses. For CS this should look like this:
#
# ```
# CS: (Computer Science, https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CS)
# ```

# %%
subjects = {}

for subject in soup.find_all(class_="subject-list"):
    # the url is relative. 
    # We can get the tail by retrieving the link out the href attribute of the a tag
    link_tail = subject.find("a").get("href")
    # concatenate the base URL and the tail of the link
    link = url + link_tail
    # the subject shortname is embedded within the <a> tag
    subject_short = subject.find("a").get_text()
    # the subject name is embedded within the span 
    subject_long = subject.span.get_text()
    # write it to the dictionary
    subjects[subject_short] = (subject_long, link)

subjects
# Out:
# {'ACCTG': ('Accounting',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ACCTG'),
#  'AEROS': ('Aerospace Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=AEROS'),
#  'ANAT': ('Neurobiology and Anatomy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ANAT'),
#  'ANES': ('Anesthesiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ANES'),
#  'ANTH': ('Anthropology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ANTH'),
#  'ARAB': ('Arabic',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ARAB'),
#  'ARCH': ('Architecture',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ARCH'),
#  'ART': ('Art',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ART'),
#  'ARTH': ('Art History',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ARTH'),
#  'ASL': ('American Sign Language',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ASL'),
#  'ASTR': ('Astronomy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ASTR'),
#  'ATFA': ('Arts Teaching in Fine Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ATFA'),
#  'ATHL': ('Athletics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ATHL'),
#  'ATMOS': ('Atmospheric Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ATMOS'),
#  'ATSM': ('Athletic Training and Sports Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ATSM'),
#  'BALLE': ('Ballet',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BALLE'),
#  'BART': ('Book Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BART'),
#  'BCOR': ('Business Core',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BCOR'),
#  'BIO C': ('Biochemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BIO%20C'),
#  'BIOEN': ('Bioengineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BIOEN'),
#  'BIOL': ('Biology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BIOL'),
#  'BLCHM': ('Biological Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BLCHM'),
#  'BMI': ('Biomedical Informatics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BMI'),
#  'BUS': ('Business',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=BUS'),
#  'CAMB': ('Cambodian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CAMB'),
#  'CECRT': ('CE Certificate',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CECRT'),
#  'CERM': ('Ceramics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CERM'),
#  'CH EN': ('Chemical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CH%20EN'),
#  'CHEM': ('Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CHEM'),
#  'CHIN': ('Chinese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CHIN'),
#  'CL CV': ('Classical Civilization',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CL%20CV'),
#  'CLCS': ('Comparative Literary and Cultural Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CLCS'),
#  'CMP': ('City & Metropolitan Planning',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CMP'),
#  'COMM': ('Communication',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=COMM'),
#  'COMP': ('Computing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=COMP'),
#  'COPTC': ('Coptic Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=COPTC'),
#  'CS': ('Computer Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CS'),
#  'CSD': ('Communication Sciences and Disorders',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CSD'),
#  'CTLE': ('Center for Teaching & Learning Excellence',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CTLE'),
#  'CVEEN': ('Civil and Environmental Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CVEEN'),
#  'DANC': ('Modern Dance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=DANC'),
#  'DENT': ('Dentistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=DENT'),
#  'DERM': ('Dermatology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=DERM'),
#  'DES': ('Design',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=DES'),
#  'DRAW': ('Drawing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=DRAW'),
#  'EAE': ('Entertainment Arts & Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=EAE'),
#  'EAS': ('English for Academic Success',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=EAS'),
#  'ECE': ('Electrical and Computer Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ECE'),
#  'ECON': ('Economics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ECON'),
#  'ECS': ('Education, Culture and Society',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ECS'),
#  'ED PS': ('Educational Psychology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ED%20PS'),
#  'EDTEC': ('Educational Technology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=EDTEC'),
#  'EDU': ('Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=EDU'),
#  'EHUM': ('Environmental Humanities',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=EHUM'),
#  'ELI': ('English Language Institute',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ELI'),
#  'ELP': ('Educational Leadership & Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ELP'),
#  'ENGIN': ('Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ENGIN'),
#  'ENGL': ('English',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ENGL'),
#  'ENTP': ('Entrepreneurship',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ENTP'),
#  'ENVST': ('Environmental and Sustainability Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ENVST'),
#  'ESSF': ('ESS Fitness Courses',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ESSF'),
#  'ETHNC': ('Ethnic Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ETHNC'),
#  'FA': ('Fine Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=FA'),
#  'FCS': ('Family and Consumer Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=FCS'),
#  'FILM': ('Film and Media Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=FILM'),
#  'FINAN': ('Finance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=FINAN'),
#  'FP MD': ('Family and Preventive Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=FP%20MD'),
#  'FRNCH': ('French',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=FRNCH'),
#  'GEO': ('Geology and Geophysics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=GEO'),
#  'GEOG': ('Geography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=GEOG'),
#  'GERM': ('German',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=GERM'),
#  'GERON': ('Gerontology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=GERON'),
#  'GLOBL': ('Utah Global',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=GLOBL'),
#  'GNDR': ('Gender Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=GNDR'),
#  'GREEK': ('Greek',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=GREEK'),
#  'H EDU': ('Health Promotion & Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=H%20EDU'),
#  'H GEN': ('Human Genetics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=H%20GEN'),
#  'HINDI': ('Hindi',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=HINDI'),
#  'HIST': ('History',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=HIST'),
#  'HLTH': ('Health',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=HLTH'),
#  'HNKLY': ('Hinckley Institute',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=HNKLY'),
#  'HONOR': ('Honors College',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=HONOR'),
#  'HSP': ('Health, Society and Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=HSP'),
#  'HUM': ('Humanities',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=HUM'),
#  'IAGE': ('International Affairs and Global Enterprise',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=IAGE'),
#  'INTMD': ('Internal Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=INTMD'),
#  'IS': ('Information Systems',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=IS'),
#  'ITAL': ('Italian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ITAL'),
#  'JAPAN': ('Japanese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=JAPAN'),
#  'KINES': ('Kinesiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=KINES'),
#  'KOREA': ('Korean',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=KOREA'),
#  'LAS': ('Latin American Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LAS'),
#  'LATIN': ('Latin',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LATIN'),
#  'LAW': ('Law',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LAW'),
#  'LDRSP': ('Leadership',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LDRSP'),
#  'LEAP': ('LEAP Program',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LEAP'),
#  'LING': ('Linguistics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LING'),
#  'LLART': ('Art and Photography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLART'),
#  'LLBUS': ('Business and Finance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLBUS'),
#  'LLCFT': ('Crafts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLCFT'),
#  'LLFW': ('Food and Wine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLFW'),
#  'LLHG': ('Home and Garden',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLHG'),
#  'LLHL': ('Healthy Living',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLHL'),
#  'LLLAN': ('Language',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLLAN'),
#  'LLMT': ('Music and Theatre',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLMT'),
#  'LLPOT': ('Potpourri',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLPOT'),
#  'LLREC': ('Recreation',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLREC'),
#  'LLWRC': ('Writing/Creative',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=LLWRC'),
#  'MATH': ('Mathematics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MATH'),
#  'MBA': ('Master Business Administration',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MBA'),
#  'MBIOL': ('Molecular Biology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MBIOL'),
#  'MD CH': ('Pharmacy - Medicinal Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MD%20CH'),
#  'MD ID': ('Interdepartmental Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MD%20ID'),
#  'MD LB': ('Medical Laboratory Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MD%20LB'),
#  'MDCRC': ('Clinical Research Center',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MDCRC'),
#  'ME EN': ('Mechanical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ME%20EN'),
#  'MET E': ('Metallurgical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MET%20E'),
#  'MG EN': ('Mining Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MG%20EN'),
#  'MGT': ('Management',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MGT'),
#  'MHA': ('Master Healthcare Administration',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MHA'),
#  'MID E': ('Middle East Language and Area Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MID%20E'),
#  'MIL S': ('Military Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MIL%20S'),
#  'MKTG': ('Marketing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MKTG'),
#  'MSE': ('Materials Science and Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MSE'),
#  'MST': ('Master of Science and Technology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MST'),
#  'MUSC': ('Music',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MUSC'),
#  'NAHTL': ('Nahuatl',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NAHTL'),
#  'NAVJO': ('Navajo',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NAVJO'),
#  'NEURO': ('Neurology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NEURO'),
#  'NEUSC': ('Neuroscience',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NEUSC'),
#  'NSURG': ('Neurosurgery',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NSURG'),
#  'NUCL': ('Nuclear Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NUCL'),
#  'NUIP': ('Nutrition and Integrative Physiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NUIP'),
#  'NURS': ('Nursing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NURS'),
#  'NV SC': ('Naval Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=NV%20SC'),
#  'OBST': ('Obstetrics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=OBST'),
#  'OC TH': ('Occupational Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=OC%20TH'),
#  'OEHS': ('Occupational and Environmental Health',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=OEHS'),
#  'OIS': ('Operations and Information Systems',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=OIS'),
#  'ONCSC': ('Oncological Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ONCSC'),
#  'OPHTH': ('Ophthalmology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=OPHTH'),
#  'ORTHO': ('Orthopedics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=ORTHO'),
#  'OSHER': ('Osher Lifelong Learning',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=OSHER'),
#  'PADMN': ('Public Administration',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PADMN'),
#  'PAS': ('Physician Assistant Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PAS'),
#  'PATH': ('Pathology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PATH'),
#  'PBHLT': ('Public Health',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PBHLT'),
#  'PCS': ('Peace and Conflict Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PCS'),
#  'PCTH': ('Pharmacotherapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PCTH'),
#  'PED': ('Pediatrics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PED'),
#  'PERS': ('Persian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PERS'),
#  'PH MD': ('Phys Med & Rehabilitation',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PH%20MD'),
#  'PH TH': ('Physical Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PH%20TH'),
#  'PH TX': ('Pharmacology and Toxicology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PH%20TX'),
#  'PHARM': ('Pharmacy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PHARM'),
#  'PHCEU': ('Pharmaceutics and Pharmaceutical Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PHCEU'),
#  'PHIL': ('Philosophy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PHIL'),
#  'PHOTO': ('Digital Photography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PHOTO'),
#  'PHS': ('Population Health Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PHS'),
#  'PHYS': ('Physics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PHYS'),
#  'PHYSL': ('Physiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PHYSL'),
#  'POLS': ('Political Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=POLS'),
#  'PREP': ('Preparatory',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PREP'),
#  'PRINT': ('Printmaking',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PRINT'),
#  'PROEA': ('Professional Education Academies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PROEA'),
#  'PROED': ('Professional Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PROED'),
#  'PROTA': ('Professional Education Technology Academy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PROTA'),
#  'PRT': ('Parks, Recreation and Tourism',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PRT'),
#  'PRTL': ('PRT Outdoor Adventure - Land',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PRTL'),
#  'PRTS': ('PRT Outdoor Adventure - Snow',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PRTS'),
#  'PRTW': ('PRT Outdoor Adventure - Water',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PRTW'),
#  'PSY': ('Psychology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PSY'),
#  'PSYCT': ('Psychiatry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PSYCT'),
#  'PTGSE': ('Portuguese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PTGSE'),
#  'PUBPL': ('Public Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=PUBPL'),
#  'QAMO': ('Quantitative Analysis of Markets and Organizations',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=QAMO'),
#  'QUECH': ('Quechua',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=QUECH'),
#  'RDLGY': ('Radiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=RDLGY'),
#  'RDONC': ('Radiation Oncology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=RDONC'),
#  'RECTH': ('Recreational Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=RECTH'),
#  'REDEV': ('Real Estate Development',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=REDEV'),
#  'RELS': ('Religious Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=RELS'),
#  'RHSCI': ('Rehabilitation Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=RHSCI'),
#  'RUSS': ('Russian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=RUSS'),
#  'SBS': ('Social and Behavioral Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SBS'),
#  'SCI': ('Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SCI'),
#  'SCLPT': ('Sculpture/Intermedia',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SCLPT'),
#  'SOC': ('Sociology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SOC'),
#  'SP ED': ('Special Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SP%20ED'),
#  'SPAN': ('Spanish',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SPAN'),
#  'SR EL': ('Senior Electives',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SR%20EL'),
#  'STAT': ('Statistics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=STAT'),
#  'STRAT': ('Strategy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=STRAT'),
#  'SURG': ('Surgery',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SURG'),
#  'SUST': ('Sustainability',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SUST'),
#  'SW': ('Social Work',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=SW'),
#  'THEA': ('Theatre',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=THEA'),
#  'UGS': ('Undergraduate Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=UGS'),
#  'UUHSC': ('Health Sciences Center',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=UUHSC'),
#  'VIET': ('Vietnamese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=VIET'),
#  'WLC': ('World Languages and Cultures',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=WLC'),
#  'WRTG': ('Writing and Rhetoric Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=WRTG'),
#  'YECU': ('Club U camps',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=YECU'),
#  'YEHS': ('High School',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=YEHS')}

# %% [markdown]
# Let's look at the entry for math:

# %%
subjects["MATH"]
# Out:
# ('Mathematics',
#  'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=MATH')

# %% [markdown]
# That's what we want.
#
# As an aside: we could have taken a different approach here. Note how the URL has a deterministic query parameter that matches the subject:
#
# ```
# class_list.html?subject=MATH
# ```
#
# We could use this to also retrieve the links if we only had the subject shortnames.

# %% [markdown]
# #### Getting a list of classes
#
# Next, it's time to get the courses. Let's look at the [website for CS](https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/class_list.html?subject=CS).
#
# We'll fetch this class list in a function where we pass in the subject name:

# %%
def getWebsiteAsSoup(url):
    """ 
    Retrieve a website and return it as a BeautifulSoup object.   
    """
    
    #user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.167 Safari/537.36'
    #headers = {'User-Agent': user_agent}
      
    # values = {'name': 'Michael Foord',
    #       'location': 'Northampton',
    #       'language': 'Python' }
    
    #data = urllib.parse.urlencode(values)
    #data = data.encode('ascii')

    #req = urllib.request.Request(url, data, headers)
    req = urllib.request.Request(url)
    with urllib.request.urlopen(req) as response:
        classlist_html = response.read()
    
    print(classlist_html)
    
    class_soup = BeautifulSoup(classlist_html, 'html.parser')
    with open('class_list.html', 'w') as new_file:
        new_file.write(str(class_soup))
        
    return class_soup

# %% [markdown]
# Let's run this function for CS and look at the output:

# %%
class_soup = getWebsiteAsSoup(subjects["CS"][1])
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n    <head>\r\n        <title>Class Schedule</title>\r\n        <meta charset="utf-8" />\r\n        <meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n        <meta name="viewport" content="width=device-width, initial-scale=1"/>\r\n        <link href="//templates.utah.edu/apps/v1/_css/main.css" rel="stylesheet" />\r\n        <link href="/uofu/stu/ClassSchedules/css/styles.css" rel="stylesheet" type="text/css" />\r\n        <link href="/uofu/stu/ClassSchedules/css/print.css" rel="stylesheet" type="text/css" media="print" />\r\n        <link rel="icon" type="image/ico" href="/uofu/stu/ClassSchedules/images/favicon.ico" />  \r\n        <meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE" />\r\n        <script src="//templates.utah.edu/apps/v1/_js/vendor/modernizr-2.6.2.min.js"></script>\r\n        <script src="/uofu/stu/ClassSchedules/scripts/jquery.min.js"></script>   \r\n        <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js"></script>\r\n        <script src="/uofu/stu/ClassSchedules/scripts/elevator.min.js"></script>\r\n        <script>\r\n            $(window).load(function(){\r\n                var elevator = new Elevator({\r\n                    mainAudio: "/uofu/stu/ClassSchedules/resources/bg.mp3",\r\n                    endAudio: "/uofu/stu/ClassSchedules/resources/ding.mp3"\r\n                });\r\n                \r\n                $(\'.elevator-button\').on(\'click\', function(e) {\r\n                    if (e.altKey) {                        \r\n                        e.preventDefault();\r\n                        elevator.elevate();\r\n                    } else {\r\n                        $(document).scrollTop(0);\r\n                    }\r\n                });\r\n            });            \r\n        </script>\r\n        <script>                 \r\n            (function (i, s, o, g, r, a, m) {\r\n                i[\'GoogleAnalyticsObject\'] = r;\r\n                i[r] = i[r] || function ()\r\n                {\r\n                    (i[r].q = i[r].q || []).push(arguments)\r\n                }\r\n                , i[r].l = 1 * new Date();\r\n                a = s.createElement(o),\r\n                        m = s.getElementsByTagName(o)[0];\r\n                a.async = 1;\r\n                a.src = g;\r\n                m.parentNode.insertBefore(a, m)\r\n            })(window, document, \'script\', \'//www.google-analytics.com/analytics.js\', \'ga\');\r\n            ga(\'create\', "UA-58881890-50", \'auto\');\r\n            ga(\'send\', \'pageview\');\r\n        </script>        \r\n    <meta charset="UTF-8" />        \r\n    </head>\r\n    <body>\r\n\r\n        <header class="uu-header" role="banner" id="top">\r\n            <div class="uu-container">\r\n                <a href="#uu-skip-target" class="skip sr-only focusable">Skip to Main Content</a>\r\n                <div class="row">\r\n                    <!-- header logo 1 -->\r\n                    <div class="col-sm-6">\r\n                        <div class="uu-logo"><a href="http://www.utah.edu/"><img src="/uofu/stu/ClassSchedules/images/U.png" alt="The University of Utah" /></a></div>\r\n                        <div class="uu-org-title"><h2><a href="http://www.utah.edu/"><img src="/uofu/stu/ClassSchedules/images/Ulogo.png" /></a></h2></div>\r\n                    </div>\r\n                </div>\r\n            </div>\r\n        </header>\r\n\r\n        <nav class="uu-nav navbar navbar-inverse" role="navigation">\r\n            <div class="uu-container">\r\n                <a href="index.html" class="uu-nav-link">Home</a>\r\n            </div>\r\n        </nav>\r\n\r\n        <div class="uu-breadcrumb">\r\n            <div class="uu-container">\r\n                <div class="row">\r\n                    <div class="col-sm-7">\r\n                        <section>\n            <h1>Computer Science</h1>\n            <h5 class="subject ...

# %%
class_soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml">\n <head>\n  <title>\n   Class Schedule\n  </title>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <link href="//templates.utah.edu/apps/v1/_css/main.css" rel="stylesheet"/>\n  <link href="/uofu/stu/ClassSchedules/css/styles.css" rel="stylesheet" type="text/css"/>\n  <link href="/uofu/stu/ClassSchedules/css/print.css" media="print" rel="stylesheet" type="text/css"/>\n  <link href="/uofu/stu/ClassSchedules/images/favicon.ico" rel="icon" type="image/ico"/>\n  <meta content="IE=10; IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>\n  <script src="//templates.utah.edu/apps/v1/_js/vendor/modernizr-2.6.2.min.js">\n  </script>\n  <script src="/uofu/stu/ClassSchedules/scripts/jquery.min.js">\n  </script>\n  <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js">\n  </script>\n  <script src="/uofu/stu/ClassSchedules/scripts/elevator.min.js">\n  </script>\n  <script>\n   $(window).load(function(){\r\n                var elevator = new Elevator({\r\n                    mainAudio: "/uofu/stu/ClassSchedules/resources/bg.mp3",\r\n                    endAudio: "/uofu/stu/ClassSchedules/resources/ding.mp3"\r\n                });\r\n                \r\n                $(\'.elevator-button\').on(\'click\', function(e) {\r\n                    if (e.altKey) {                        \r\n                        e.preventDefault();\r\n                        elevator.elevate();\r\n                    } else {\r\n                        $(document).scrollTop(0);\r\n                    }\r\n                });\r\n            });\n  </script>\n  <script>\n   (function (i, s, o, g, r, a, m) {\r\n                i[\'GoogleAnalyticsObject\'] = r;\r\n                i[r] = i[r] || function ()\r\n                {\r\n                    (i[r].q = i[r].q || []).push(arguments)\r\n                }\r\n                , i[r].l = 1 * new Date();\r\n                a = s.createElement(o),\r\n                        m = s.getElementsByTagName(o)[0];\r\n                a.async = 1;\r\n                a.src = g;\r\n                m.parentNode.insertBefore(a, m)\r\n            })(window, document, \'script\', \'//www.google-analytics.com/analytics.js\', \'ga\');\r\n            ga(\'create\', "UA-58881890-50", \'auto\');\r\n            ga(\'send\', \'pageview\');\n  </script>\n  <meta charset="utf-8"/>\n </head>\n <body>\n  <header class="uu-header" id="top" role="banner">\n   <div class="uu-container">\n    <a class="skip sr-only focusable" href="#uu-skip-target">\n     Skip to Main Content\n    </a>\n    <div class="row">\n     <!-- header logo 1 -->\n     <div class="col-sm-6">\n      <div class="uu-logo">\n       <a href="http://www.utah.edu/">\n        <img alt="The University of Utah" src="/uofu/stu/ClassSchedules/images/U.png"/>\n       </a>\n      </div>\n      <div class="uu-org-title">\n       <h2>\n        <a href="http://www.utah.edu/">\n         <img src="/uofu/stu/ClassSchedules/images/Ulogo.png"/>\n        </a>\n       </h2>\n      </div>\n     </div>\n    </div>\n   </div>\n  </header>\n  <nav class="uu-nav navbar navbar-inverse" role="navigation">\n   <div class="uu-container">\n    <a class="uu-nav-link" href="index.html">\n     Home\n    </a>\n   </div>\n  </nav>\n  <div class="uu-breadcrumb">\n   <div class="uu-container">\n    <div class="row">\n     <div class="col-sm-7">\n      <section>\n       <h1>\n        Computer Science\n       </h1>\n       <h5 class="subject-info">\n        Spring 2019 Class Schedule\n       </h5>\n      </section>\n     </div>\n     <div class="col-sm-5">\n      <div class="subject-info">\n       <section>\n        <ul>\n         <li>\n          Location: MEB 3190\n         </li>\n         <li>\n          Phone: 801-581-8224\n         </li>\n        </ul>\n       </section>\n      </div>\n     </div>\n    </div>\n   </div> ...

# %% [markdown]
# Unfortunately, the HTML that is returned by this website is not valid HTML. Take a look at this section:
#
# ```html
# <td colspan="15">
# <p>
# <span>Sections 2 - 6 belong to this lecture. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. </span>
# </p>
# <ul>
# </ul>
# </td></tr></table></div></div></div></div></main></section></body></html>
#
#
# <tr class="even">
# <td><a name="6635"></a><span>6635</span></td>
# ```
#
# Here, the table, body and html tags are terminated in the middle of the HTML document. This is likely an error in the website code that is dynamically generated. However, this doesn't appear in your browsers DOM, so it's likely that the web server generates code differntly for our scraper (python user agent) than it does for our browser.
#
# We have three choices here:
#
#  1. Figure out the header information that returns the correct HTML with urllib
#  2. Use a browser automatization tool such as [selenium](http://www.seleniumhq.org/)
#  3. Manually fix that error in the html and re-load it.
#
# I tried option 1 (see the commented-out code above), but I couldn't find a user-agent and browser config that got me a valid response, so I'm going for the (very hacky) option 3 and fix the returned HTML by hand in an editor, then re-load it:

# %%
class_soup = BeautifulSoup(open("class_list_modified.html"), "html.parser")

# %%
class_soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Class Schedule</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="//templates.utah.edu/apps/v1/_css/main.css" rel="stylesheet"/>
# <link href="/uofu/stu/ClassSchedules/css/styles.css" rel="stylesheet" type="text/css"/>
# <link href="/uofu/stu/ClassSchedules/css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/uofu/stu/ClassSchedules/images/favicon.ico" rel="icon" type="image/ico"/>
# <meta content="IE=10; IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>
# <script src="//templates.utah.edu/apps/v1/_js/vendor/modernizr-2.6.2.min.js"></script>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.min.js"></script>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js"></script>
# <script src="/uofu/stu/ClassSchedules/scripts/elevator.min.js"></script>
# <script>
#             $(window).load(function(){
#                 var elevator = new Elevator({
#                     mainAudio: "/uofu/stu/ClassSchedules/resources/bg.mp3",
#                     endAudio: "/uofu/stu/ClassSchedules/resources/ding.mp3"
#                 });
#
#                 $('.elevator-button').on('click', function(e) {
#                     if (e.altKey) {
#                         e.preventDefault();
#                         elevator.elevate();
#                     } else {
#                         $(document).scrollTop(0);
#                     }
#                 });
#             });
#         </script>
# <script>
#             (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function ()
#                 {
#                     (i[r].q = i[r].q || []).push(arguments)
#                 }
#                 , i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#             ga('create', "UA-58881890-50", 'auto');
#             ga('send', 'pageview');
#         </script>
# <meta charset="utf-8"/>
# </head>
# <body>
# <header class="uu-header" id="top" role="banner">
# <div class="uu-container">
# <a class="skip sr-only focusable" href="#uu-skip-target">Skip to Main Content</a>
# <div class="row">
# <!-- header logo 1 -->
# <div class="col-sm-6">
# <div class="uu-logo"><a href="http://www.utah.edu/"><img alt="The University of Utah" src="/uofu/stu/ClassSchedules/images/U.png"/></a></div>
# <div class="uu-org-title"><h2><a href="http://www.utah.edu/"><img src="/uofu/stu/ClassSchedules/images/Ulogo.png"/></a></h2></div>
# </div>
# </div>
# </div>
# </header>
# <nav class="uu-nav navbar navbar-inverse" role="navigation">
# <div class="uu-container">
# <a class="uu-nav-link" href="index.html">Home</a>
# </div>
# </nav>
# <div class="uu-breadcrumb">
# <div class="uu-container">
# <div class="row">
# <div class="col-sm-7">
# <section>
# <h1>Computer Science</h1>
# <h5 class="subject-info">Spring 2019 Class Schedule</h5>
# </section>
# </div>
# <div class="col-sm-5">
# <div class="subject-info">
# <section>
# <ul>
# <li>Location: MEB 3190</li>
# <li>Phone: 801-581-8224</li>
# </ul>
# </section>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section>
# <!-- ************* MAIN CONTENT AREA ****************** -->
# <main class="uu-main class-details" role="main">
# <div class="uu-container" id="uu-skip-target">
# <div class="top-content">
# <div class="row">
# <div class="col-sm-8">
# <div class="panel panel-default">
# <div class="panel-heading">Departmental Notes</div>
# <div class="panel-body">
# <p><span>For course descriptions and pre-requisite information click on the subject column next to the appropriate catalog number.</span></p>
# <p><span>THIS DEPARTMENT ENFORCES UNDERGRADUATE PREREQUISITES. Please note that the registration system may not factor in transfer work when determining if prerequisites have been met.   If you are unable to register for a course and think you have met the prerequisite(s), please contact an advisor from this department to inquire about obtaining a permission code.  You may be administratively dropped from a course if the prerequisite has not been met.</span></p>
# </div>
# </div>
# </div>
# <div class="col-sm-4">
# <div class="panel panel-default">
# <div class="panel-heading">Resources</div>
# <div class="panel-body">
# <ul>
# <li><a href="http://registrar.utah.edu/register/schedule-builder.php">Schedule Builder</a></li>
# <li><a href="https://registrar.utah.edu/handbook/">Student Handbook</a><span class="small"> (dates, deadlines, and policy information)</span></li>
# <li><a href="http://catalog.utah.edu/">General Catalog Information</a></li>
# <li><a href="http://registrar.utah.edu/academic-calendars/spring2019.php">Academic Calendar</a></li>
# <li><a href="http://www.bookstore.utah.edu/UTAH/SelectTermDept.aspx">Textbook Requirements</a></li>
# <li><a href="/uofu/stu/ClassSchedules/main/1194/">Spring 2019 Class Schedule</a></li>
# <li>
# <a href="/uofu/stu/ClassSchedules/main/1194/attribute_list.html?listType=GENOTHER">
#                                                     List of Attribute Definitions
#                                                 </a>
# </li>
# <li><a href="javascript:window.history.back();">Previous Screen</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="advisors row">
# <div class=" col-sm-12 ">
# <div class="panel panel-default">
# <div class="panel-heading">Departmental Advisors</div>
# <table class="table table-bordered table-striped">
# <tr>
# <th>Advisor Type</th>
# <th>Name</th>
# <th>Contact Information</th>
# </tr>
# <tr>
# <td>Undergraduate Studies Office</td>
# <td>Vicki Jackson</td>
# <td>MEB 3190</td>
# </tr>
# <tr>
# <td>Graduate Studies Office</td>
# <td>Leslie Wallwork</td>
# <td>MEB 3190</td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# <!-- Search -->
# <div>
# <script type="text/javascript">
#                 $(document).ready(function () {
#                     var advanced = false;
#                     if (advanced) {
#                         $('.search').toggleClass('search-expanded', 700);
#                         $(".advanced-search").toggle();
#                     }
#
#                     $('form').validate({
#                         submitHandler: function (form) {
#                             var validator = $.data(form, "validator");
#                             $("#classDetailsTable").hide();
#                             $("#noneFound").hide();
#                             if(!($("#search").val() || ($("#catalog_number").val() || $("#subject").val() || $("#title").val() || $("#session").val() || $("#instructor_fname").val() || $("#instructor_lname").val() || $("#time").val() || $("#units").val() || $("#gen-ed_bachelor_codes").val() || $("#other-course-attributes").val()) || $("#monday").prop('checked') || $("#tuesday").prop('checked') || $("#wednesday").prop('checked') || $("#thursday").prop('checked') || $("#friday").prop('checked') || $("#saturday").prop('checked') || $("#sunday").prop('checked') || $("#all").prop('checked'))) {
#                                 validator.showErrors({"searchString": "Please select search parameters"});
#                                 return false;
#                             }
#                             $("#searching").show();
#                             $("#advanced").val($("#advancedSearch").is(":visible"));
#                             if (!$("#advancedSearch").is(":visible")) {
#                                 clearParameters(false);
#                             }
#                             form.submit();
#                         }
#                     });
#
#                 });
#
#                 function clearParameters(clearAll){
#                     $(".adInput").val("");
#                     $(".adCheckbox").prop("checked", false);
#                     if(clearAll){
#                         $("#search").val("");
#                         $("#all_classes").prop("checked", true);
#                     }
#                 }
#
#             </script>
# <div class="row search-area">
# <div class="col-sm-12">
# <form action="search.html" method="post">
# <div class="form-group form-inline ">
# <div class="row">
# <div class="col-md-6">
# <label for="search">Search: </label> <input class="form-control search-box" id="search" name="searchString" placeholder="Subject Code and/or Catalog Number" type="text" value=""/>
# </div>
# <div class="col-md-3 center-radio">
# <label for="available_seats"> <input id="available_seats" name="availableSeats" type="radio" value="true"/> Classes with available seats</label>
# </div>
# <div class="col-md-3 center-radio">
# <label for="all_classes"> <input checked="checked" id="all_classes" name="availableSeats" type="radio" value="false"/> All Classes</label>
# </div>
# </div>
# <div class="row">
# <div class="col-md-6">
# <a class="small advanced-link" href="#">Advanced Search</a>
# </div>
# </div>
# </div>
# <div class="panel panel-default space-top advanced-search" id="advancedSearch" style="display: none">
# <div class="panel-heading lighter">
#                                 Advanced Search
#                             </div>
# <div class="panel-body form-group">
# <div class="row">
# <div class="col-md-2">
# <label for="catalog_number">Catalog #</label><br/>
# <input class="form-control adInput" id="catalog_number" name="catalogNumber" type="number" value=""/><br/>
# </div>
# <div class="col-md-5">
# <label for="subject">Subject</label><br/>
# <select class="form-control adInput" id="subject" name="subject">
# <option value="">All Subjects</option>
# <option value="ACCTG">ACCTG - Accounting</option>
# <option value="AEROS">AEROS - Aerospace Studies</option>
# <option value="ANAT">ANAT - Neurobiology and Anatomy</option>
# <option value="ANES">ANES - Anesthesiology</option>
# <option value="ANTH">ANTH - Anthropology</option>
# <option value="ARAB">ARAB - Arabic</option>
# <option value="ARCH">ARCH - Architecture</option>
# <option value="ART">ART - Art</option>
# <option value="ARTH">ARTH - Art History</option>
# <option value="ASL">ASL - American Sign Language</option>
# <option value="ASTR">ASTR - Astronomy</option>
# <option value="ATFA">ATFA - Arts Teaching in Fine Arts</option>
# <option value="ATHL">ATHL - Athletics</option>
# <option value="ATMOS">ATMOS - Atmospheric Sciences</option>
# <option value="ATSM">ATSM - Athletic Training and Sports Medicine</option>
# <option value="BALLE">BALLE - Ballet</option>
# <option value="BART">BART - Book Arts</option>
# <option value="BCOR">BCOR - Business Core</option>
# <option value="BIO C">BIO C - Biochemistry</option>
# <option value="BIOEN">BIOEN - Bioengineering</option>
# <option value="BIOL">BIOL - Biology</option>
# <option value="BLCHM">BLCHM - Biological Chemistry</option>
# <option value="BMI">BMI - Biomedical Informatics</option>
# <option value="BUS">BUS - Business</option>
# <option value="CAMB">CAMB - Cambodian</option>
# <option value="CECRT">CECRT - CE Certificate</option>
# <option value="CERM">CERM - Ceramics</option>
# <option value="CH EN">CH EN - Chemical Engineering</option>
# <option value="CHEM">CHEM - Chemistry</option>
# <option value="CHIN">CHIN - Chinese</option>
# <option value="CL CV">CL CV - Classical Civilization</option>
# <option value="CLCS">CLCS - Comparative Literary and Cultural Studies</option>
# <option value="CMP">CMP - City &amp; Metropolitan Planning</option>
# <option value="COMM">COMM - Communication</option>
# <option value="COMP">COMP - Computing</option>
# <option value="COPTC">COPTC - Coptic Studies</option>
# <option value="CS">CS - Computer Science</option>
# <option value="CSD">CSD - Communication Sciences and Disorders</option>
# <option value="CTLE">CTLE - Center for Teaching &amp; Learning Excellence</option>
# <option value="CVEEN">CVEEN - Civil and Environmental Engineering</option>
# <option value="DANC">DANC - Modern Dance</option>
# <option value="DENT">DENT - Dentistry</option>
# <option value="DERM">DERM - Dermatology</option>
# <option value="DES">DES - Design</option>
# <option value="DRAW">DRAW - Drawing</option>
# <option value="EAE">EAE - Entertainment Arts &amp; Engineering</option>
# <option value="EAS">EAS - English for Academic Success</option>
# <option value="ECE">ECE - Electrical and Computer Engineering</option>
# <option value="ECON">ECON - Economics</option>
# <option value="ECS">ECS - Education, Culture and Society</option>
# <option value="ED PS">ED PS - Educational Psychology</option>
# <option value="EDTEC">EDTEC - Educational Technology</option>
# <option value="EDU">EDU - Education</option>
# <option value="EHUM">EHUM - Environmental Humanities</option>
# <option value="ELI">ELI - English Language Institute</option>
# <option value="ELP">ELP - Educational Leadership &amp; Policy</option>
# <option value="ENGIN">ENGIN - Engineering</option>
# <option value="ENGL">ENGL - English</option>
# <option value="ENTP">ENTP - Entrepreneurship</option>
# <option value="ENVST">ENVST - Environmental and Sustainability Studies</option>
# <option value="ESSF">ESSF - ESS Fitness Courses</option>
# <option value="ETHNC">ETHNC - Ethnic Studies</option>
# <option value="FA">FA - Fine Arts</option>
# <option value="FCS">FCS - Family and Consumer Studies</option>
# <option value="FILM">FILM - Film and Media Arts</option>
# <option value="FINAN">FINAN - Finance</option>
# <option value="FP MD">FP MD - Family and Preventive Medicine</option>
# <option value="FRNCH">FRNCH - French</option>
# <option value="GEO">GEO - Geology and Geophysics</option>
# <option value="GEOG">GEOG - Geography</option>
# <option value="GERM">GERM - German</option>
# <option value="GERON">GERON - Gerontology</option>
# <option value="GLOBL">GLOBL - Utah Global</option>
# <option value="GNDR">GNDR - Gender Studies</option>
# <option value="GREEK">GREEK - Greek</option>
# <option value="H EDU">H EDU - Health Promotion &amp; Education</option>
# <option value="H GEN">H GEN - Human Genetics</option>
# <option value="HINDI">HINDI - Hindi</option>
# <option value="HIST">HIST - History</option>
# <option value="HLTH">HLTH - Health</option>
# <option value="HNKLY">HNKLY - Hinckley Institute</option>
# <option value="HONOR">HONOR - Honors College</option>
# <option value="HSP">HSP - Health, Society and Policy</option>
# <option value="HUM">HUM - Humanities</option>
# <option value="IAGE">IAGE - International Affairs and Global Enterprise</option>
# <option value="INTMD">INTMD - Internal Medicine</option>
# <option value="IS">IS - Information Systems</option>
# <option value="ITAL">ITAL - Italian</option>
# <option value="JAPAN">JAPAN - Japanese</option>
# <option value="KINES">KINES - Kinesiology</option>
# <option value="KOREA">KOREA - Korean</option>
# <option value="LAS">LAS - Latin American Studies</option>
# <option value="LATIN">LATIN - Latin</option>
# <option value="LAW">LAW - Law</option>
# <option value="LDRSP">LDRSP - Leadership</option>
# <option value="LEAP">LEAP - LEAP Program</option>
# <option value="LING">LING - Linguistics</option>
# <option value="LLART">LLART - Art and Photography</option>
# <option value="LLBUS">LLBUS - Business and Finance</option>
# <option value="LLCFT">LLCFT - Crafts</option>
# <option value="LLFW">LLFW - Food and Wine</option>
# <option value="LLHG">LLHG - Home and Garden</option>
# <option value="LLHL">LLHL - Healthy Living</option>
# <option value="LLLAN">LLLAN - Language</option>
# <option value="LLMT">LLMT - Music and Theatre</option>
# <option value="LLPOT">LLPOT - Potpourri</option>
# <option value="LLREC">LLREC - Recreation</option>
# <option value="LLWRC">LLWRC - Writing/Creative</option>
# <option value="MATH">MATH - Mathematics</option>
# <option value="MBA">MBA - Master Business Administration</option>
# <option value="MBIOL">MBIOL - Molecular Biology</option>
# <option value="MD CH">MD CH - Pharmacy - Medicinal Chemistry</option>
# <option value="MD ID">MD ID - Interdepartmental Medicine</option>
# <option value="MD LB">MD LB - Medical Laboratory Science</option>
# <option value="MDCRC">MDCRC - Clinical Research Center</option>
# <option value="ME EN">ME EN - Mechanical Engineering</option>
# <option value="MET E">MET E - Metallurgical Engineering</option>
# <option value="MG EN">MG EN - Mining Engineering</option>
# <option value="MGT">MGT - Management</option>
# <option value="MHA">MHA - Master Healthcare Administration</option>
# <option value="MID E">MID E - Middle East Language and Area Studies</option>
# <option value="MIL S">MIL S - Military Science</option>
# <option value="MKTG">MKTG - Marketing</option>
# <option value="MSE">MSE - Materials Science and Engineering</option>
# <option value="MST">MST - Master of Science and Technology</option>
# <option value="MUSC">MUSC - Music</option>
# <option value="NAHTL">NAHTL - Nahuatl</option>
# <option value="NAVJO">NAVJO - Navajo</option>
# <option value="NEURO">NEURO - Neurology</option>
# <option value="NEUSC">NEUSC - Neuroscience</option>
# <option value="NSURG">NSURG - Neurosurgery</option>
# <option value="NUCL">NUCL - Nuclear Engineering</option>
# <option value="NUIP">NUIP - Nutrition and Integrative Physiology</option>
# <option value="NURS">NURS - Nursing</option>
# <option value="NV SC">NV SC - Naval Science</option>
# <option value="OBST">OBST - Obstetrics</option>
# <option value="OC TH">OC TH - Occupational Therapy</option>
# <option value="OEHS">OEHS - Occupational and Environmental Health</option>
# <option value="OIS">OIS - Operations and Information Systems</option>
# <option value="ONCSC">ONCSC - Oncological Sciences</option>
# <option value="OPHTH">OPHTH - Ophthalmology</option>
# <option value="ORTHO">ORTHO - Orthopedics</option>
# <option value="OSHER">OSHER - Osher Lifelong Learning</option>
# <option value="PADMN">PADMN - Public Administration</option>
# <option value="PAS">PAS - Physician Assistant Studies</option>
# <option value="PATH">PATH - Pathology</option>
# <option value="PBHLT">PBHLT - Public Health</option>
# <option value="PCS">PCS - Peace and Conflict Studies</option>
# <option value="PCTH">PCTH - Pharmacotherapy</option>
# <option value="PED">PED - Pediatrics</option>
# <option value="PERS">PERS - Persian</option>
# <option value="PH MD">PH MD - Phys Med &amp; Rehabilitation</option>
# <option value="PH TH">PH TH - Physical Therapy</option>
# <option value="PH TX">PH TX - Pharmacology and Toxicology</option>
# <option value="PHARM">PHARM - Pharmacy</option>
# <option value="PHCEU">PHCEU - Pharmaceutics and Pharmaceutical Chemistry</option>
# <option value="PHIL">PHIL - Philosophy</option>
# <option value="PHOTO">PHOTO - Digital Photography</option>
# <option value="PHS">PHS - Population Health Sciences</option>
# <option value="PHYS">PHYS - Physics</option>
# <option value="PHYSL">PHYSL - Physiology</option>
# <option value="POLS">POLS - Political Science</option>
# <option value="PREP">PREP - Preparatory</option>
# <option value="PRINT">PRINT - Printmaking</option>
# <option value="PROEA">PROEA - Professional Education Academies</option>
# <option value="PROED">PROED - Professional Education</option>
# <option value="PROTA">PROTA - Professional Education Technology Academy</option>
# <option value="PRT">PRT - Parks, Recreation and Tourism</option>
# <option value="PRTL">PRTL - PRT Outdoor Adventure - Land</option>
# <option value="PRTS">PRTS - PRT Outdoor Adventure - Snow</option>
# <option value="PRTW">PRTW - PRT Outdoor Adventure - Water</option>
# <option value="PSY">PSY - Psychology</option>
# <option value="PSYCT">PSYCT - Psychiatry</option>
# <option value="PTGSE">PTGSE - Portuguese</option>
# <option value="PUBPL">PUBPL - Public Policy</option>
# <option value="QAMO">QAMO - Quantitative Analysis of Markets and Organizations</option>
# <option value="QUECH">QUECH - Quechua</option>
# <option value="RDLGY">RDLGY - Radiology</option>
# <option value="RDONC">RDONC - Radiation Oncology</option>
# <option value="RECTH">RECTH - Recreational Therapy</option>
# <option value="REDEV">REDEV - Real Estate Development</option>
# <option value="RELS">RELS - Religious Studies</option>
# <option value="RHSCI">RHSCI - Rehabilitation Sciences</option>
# <option value="RUSS">RUSS - Russian</option>
# <option value="SBS">SBS - Social and Behavioral Science</option>
# <option value="SCI">SCI - Science</option>
# <option value="SCLPT">SCLPT - Sculpture/Intermedia</option>
# <option value="SOC">SOC - Sociology</option>
# <option value="SP ED">SP ED - Special Education</option>
# <option value="SPAN">SPAN - Spanish</option>
# <option value="SR EL">SR EL - Senior Electives</option>
# <option value="STAT">STAT - Statistics</option>
# <option value="STRAT">STRAT - Strategy</option>
# <option value="SURG">SURG - Surgery</option>
# <option value="SUST">SUST - Sustainability</option>
# <option value="SW">SW - Social Work</option>
# <option value="THEA">THEA - Theatre</option>
# <option value="UGS">UGS - Undergraduate Studies</option>
# <option value="UUHSC">UUHSC - Health Sciences Center</option>
# <option value="VIET">VIET - Vietnamese</option>
# <option value="WLC">WLC - World Languages and Cultures</option>
# <option value="WRTG">WRTG - Writing and Rhetoric Studies</option>
# <option value="YECU">YECU - Club U camps</option>
# <option value="YEHS">YEHS - High School</option>
# </select>
# </div>
# <div class="col-md-5">
# <label for="title">Title</label><br/>
# <input class="form-control adInput" id="title" name="title" type="text" value=""/>
# </div>
# </div>
# <div class="row">
# <div class="col-md-2">
# <label for="session">Session</label><br/>
# <select class="form-control adInput" id="session" name="session">
# <option value="">Any Session</option>
# <option value="1">Session 1 - Full semester</option>
# <option value="2">Session 2 - First half semester</option>
# <option value="3">Session 3 - Second half semester</option>
# <option value="4">Session 4 - Miscellaneous</option>
# </select><br/>
# </div>
# <div class="col-md-5">
# <label for="instructor_fname">Instructor First Name:</label>
# <input class="form-control adInput" id="instructor_fname" name="firstName" type="text" value=""/>
# </div>
# <div class="col-md-5">
# <label for="instructor_lname">Instructor Last Name:</label>
# <input class="form-control adInput" id="instructor_lname" name="lastName" type="text" value=""/>
# </div>
# </div>
# <div class="row">
# <div class="col-md-2">
# <label for="time">Time</label><br/>
# <select class="form-control adInput" id="time" name="time">
# <option value="">Any Time</option>
# <option value="M">Morning</option>
# <option value="A">Afternoon</option>
# <option value="E">Evening</option>
# </select>
# </div>
# <div class="col-md-10">
# <fieldset>
# <legend>Days</legend>
# <label for="monday">Monday <input class="adCheckbox" id="monday" name="monday" type="checkbox" value="true"/><input name="_monday" type="hidden" value="on"/></label>
# <label for="tuesday">Tuesday <input class="adCheckbox" id="tuesday" name="tuesday" type="checkbox" value="true"/><input name="_tuesday" type="hidden" value="on"/></label>
# <label for="wednesday">Wednesday <input class="adCheckbox" id="wednesday" name="wednesday" type="checkbox" value="true"/><input name="_wednesday" type="hidden" value="on"/></label>
# <label for="thursday">Thursday <input class="adCheckbox" id="thursday" name="thursday" type="checkbox" value="true"/><input name="_thursday" type="hidden" value="on"/></label>
# <label for="friday">Friday <input class="adCheckbox" id="friday" name="friday" type="checkbox" value="true"/><input name="_friday" type="hidden" value="on"/></label>
# <label for="saturday">Saturday <input class="adCheckbox" id="saturday" name="saturday" type="checkbox" value="true"/><input name="_saturday" type="hidden" value="on"/></label>
# <label for="sunday">Sunday <input class="adCheckbox" id="sunday" name="sunday" type="checkbox" value="true"/><input name="_sunday" type="hidden" value="on"/></label>
# <label for="all">All <input class="adCheckbox" id="all" name="allDays" type="checkbox" value="true"/><input name="_allDays" type="hidden" value="on"/></label>
# </fieldset>
# </div>
# </div>
# <div class="row">
# <div class="col-md-2">
# <label for="units">Units</label><br/>
# <input class="form-control adInput" id="units" name="units" type="number" value=""/><br/>
# </div>
# <div class="col-md-5">
# <label for="gen-ed_bachelor_codes">Gen Ed &amp; Bachelor Degree Codes</label>
# <select class="form-control adInput" id="gen-ed_bachelor_codes" name="degreeCode">
# <option value=""> </option>
# <option value="AI">AI - American Institutions</option>
# <option value="AS">AS - Applied Science</option>
# <option value="BF">BF - Social/Behavioral Science Exploration</option>
# <option value="CW">CW - Upper Division Communication/Writing</option>
# <option value="DV">DV - Diversity</option>
# <option value="FF">FF - Fine Art Exploration</option>
# <option value="HF">HF - Humanities Exploration</option>
# <option value="IR">IR - International Requirement</option>
# <option value="QA">QA - Quantitative Reasoning-Math</option>
# <option value="QB">QB - Quantitative Reasoning-Statistics/Logic</option>
# <option value="QI">QI - Quantitative Reasoning BS</option>
# <option value="QR">QR - Quantitative Reasoning-Math <u>and</u> Quantitative Reasoning-Statistics/Logic</option>
# <option value="SF">SF - Physical/Life Science Exploration</option>
# <option value="WR1">WR1 - Writing Requirement 1</option>
# <option value="WR2">WR2 - Writing Requirement 2</option>
# </select>
# </div>
# <div class="col-md-5">
# <label for="other-course-attributes">Other Course Attributes</label>
# <select class="form-control adInput" id="other-course-attributes" name="courseAttributes">
# <option value=""></option>
# <option value="AOCE">AOCE - Continuing Education</option>
# <option value="BLKU">BLKU - BlockU</option>
# <option value="CEL">CEL - Community Engaged Learning</option>
# <option value="CLAC">CLAC - Cultures and Languages Across the Curriculum</option>
# <option value="CNTC">CNTC - Contract Classes</option>
# <option value="EGLA">EGLA - Eccles Global Learning Abroad</option>
# <option value="FLXU">FLXU - Flexible Schedule</option>
# <option value="HBRD">HBRD - Hybrid Classes</option>
# <option value="HON">HON - Honors Course</option>
# <option value="IVC">IVC - Interactive Video Conferencing</option>
# <option value="LEAP">LEAP - LEAP</option>
# <option value="OMBA">OMBA - Online MBA</option>
# <option value="ONLN">ONLN - Online</option>
# <option value="PACE">PACE - Professional and Community Education</option>
# <option value="PMBA">PMBA - Professional MBA</option>
# <option value="SAP">SAP - Study Abroad Program</option>
# <option value="SUSC">SUSC - Sustainability - Complete</option>
# <option value="SUSL">SUSL - Sustainability - Limited</option>
# <option value="XMBA1">XMBA1 - Executive Education 1</option>
# </select>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 text-right">
# <a class="small" href="#" onclick="clearParameters(true);">Clear</a>
# </div>
# </div>
# </div>
# </div>
# <input id="advanced" name="advanced" type="hidden" value="false"/>
# <input class="btn btn-primary search" type="submit" value="Search"/>
# </form>
# <br/>
# <div class="col-md-12 text-center" id="searching" style="display: none;">
#                         Searching...
#                     </div>
# </div>
# </div>
# </div>
# <div class="alert alert-info" role="alert">
# <span class="allcaps">Attention:</span> Classroom assignments may change between the time you register and when classes begin. Please check your class schedule for the latest classroom location information before attending class.
#                     </div>
# <div class="codes">
#                         Day Codes: Mo=Monday Tu=Tuesday We=Wednesday Th=Thursday Fr=Friday Sa=Saturday Su=Sunday
#                     </div>
# <!-- Class Details Table -->
# <div>
# <div class="row">
# <div class="col-sm-12">
# <table class="table table-bordered table-striped main-table class-details-table" id="classDetailsTable">
# <thead><tr>
# <th class="nowrap">Class #</th>
# <th>Subject <span class="glyphs"></span></th>
# <th class="nowrap">Cat. #</th>
# <th>Sec.</th>
# <th>Component</th>
# <th>Units</th>
# <th>Title</th>
# <th class="nowrap">Days/Time &amp; Session</th>
# <th>Location</th>
# <th><a href="#">Class Attrs</a></th>
# <th>Instructor</th>
# <th><a href="#">Feed back</a></th>
# <th>Pre Req</th>
# <th>Fees</th>
# </tr>
# </thead>
# <tr class="odd">
# <td><a name="6634"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1001&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1001">1001</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  1.5</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/6634/CS_1000_Syllabus_Spring_2019.pdf">Eng Computing MATLAB</a>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>03:00PM-04:20PM</span> <br/>
# </p>
# <p>
# <a href="http://registrar.utah.edu/academic-calendars/spring2019.php" target="_blank">Session: First Half</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L110</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0080076/teaching/index.hml" target="_blank">DE ST GERMAIN, J. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7140" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 6 belong to this lecture. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="6635"></a><span>6635</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1001&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1001">1001</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Eng Computing MATLAB</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# <p>
# <a href="http://registrar.utah.edu/academic-calendars/spring2019.php" target="_blank">Session: First Half</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L226</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0080076/teaching/index.hml" target="_blank">DE ST GERMAIN, J. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7140" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8267"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 -8 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This course may be waived by passing a proficiency test. See <a href="http://www.cs.utah.edu/placement" target="_blank">http://www.cs.utah.edu/placement</a> for details. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="8268"></a><span>8268</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8269"></a><span>8269</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="8270"></a><span>8270</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8266"></a><span>8266</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10330"></a><span>10330</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="11186"></a><span>11186</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6645"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="https://utah.instructure.com/courses/542520/assignments/syllabus">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=GC" target="_blank">GC 1900</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 002 - 007 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This course requires a proficiency test or the required pre-requisites in order to register. Go to <a href="http://www.cs.utah.edu/placement" target="_blank">http://www.cs.utah.edu/placement</a> for the proficiency test required to waive CS 1030. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="8801"></a><span>8801</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6646"></a><span>6646</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6647"></a><span>6647</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6648"></a><span>6648</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6649"></a><span>6649</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6650"></a><span>6650</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15689"></a><span>15689</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15754"></a><span>15754</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>009</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="16563"></a><span>16563</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>010</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>05:15PM-06:05PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7911"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/7911/CS2100registrar.pdf">Discrete Structures</a>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# ...
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="18661"></a><span>18661</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6960&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6960">6960</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Fund. of Cloud Systems</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WBB" target="_blank">WBB 617</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6007330/teaching/index.hml" target="_blank">JI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 5960 017</li>
# <li>ECE 6960 017</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="12956"></a><span>12956</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6963&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6963">6963</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~mflatt/cs6963/">Functional Programming</a>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 1460</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0176314/teaching/index.hml" target="_blank">FLATT, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6703"></a><span>6703</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7930&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7930">7930</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>SoC Colloquium</span>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>09:40AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 2250</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0237293/teaching/index.hml" target="_blank">WHITAKER, R. T.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15197"></a><span>15197</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7931&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7931">7931</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://www.cs.utah.edu/~srikumar/cs7931">Computer Vision Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>10:45AM-11:45AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3490</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6009067/teaching/index.hml" target="_blank">RAMALINGAM, S.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=17506" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="7475"></a><span>7475</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7933&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7933">7933</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Graphics Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>12:10PM-01:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002542/teaching/index.hml" target="_blank">KAVAN, L.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7298"></a><span>7298</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7934&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7934">7934</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://www.eng.utah.edu/~csl-sem/">Computer Systems Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3485</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0031750/teaching/index.hml" target="_blank">EIDE, E. N.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="10366"></a><span>10366</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7935&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7935">7935</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Natural Lang. Processing Sem.</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>11:00AM-12:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028599/teaching/index.hml" target="_blank">RILOFF, E. M.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u0929025/teaching/index.hml" target="_blank">SRIKUMAR, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15196"></a><span>15196</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7936&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7936">7936</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://pubweb.eng.utah.edu/~cs7936/">Security Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3485</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0982243/teaching/index.hml" target="_blank">DENNING, T.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8786"></a><span>8786</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7937&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7937">7937</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Arch/VLSI</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>01:30PM-02:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB RM" target="_blank">MEB RM TBA</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6009029/teaching/index.hml" target="_blank">NAZM BOJNORDI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Class meets in MEB 3383. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="7665"></a><span>7665</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7938&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7938">7938</a>
# </td>
# <td>002</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Image Analysis Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Mo</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0492366/teaching/index.hml" target="_blank">JOSHI, S.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>BIOEN 6810 001</li>
# <li>ECE 6960 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="6914"></a><span>6914</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7939&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7939">7939</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://pubweb.eng.utah.edu/~cs7939/">Robotics</a>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0029780/teaching/index.hml" target="_blank">HOLLERBACH, J. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ME EN 7960 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9105"></a><span>9105</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7941&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7941">7941</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~jeffp/teaching/cs7941.html">Data Science Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Th</span> / <span>12:15PM-01:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0684549/teaching/index.hml" target="_blank">PHILLIPS, J.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=9822" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9161"></a><span>9161</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7942&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7942">7942</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Visualization Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0632547/teaching/index.hml" target="_blank">PASCUCCI, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in WEB 3780. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="11417"></a><span>11417</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7943&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7943">7943</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Networking Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3515</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852541/teaching/index.hml" target="_blank">VAN DER MERWE, J. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15926"></a><span>15926</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7944&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7944">7944</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://qed.cs.utah.edu/classes/cs-7944-computational-narrative-seminar">Comp Narrative Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Mo</span> / <span>11:00AM-12:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3490</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6014318/teaching/index.hml" target="_blank">CARDONA-RIVERA, R.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u6006841/teaching/index.hml" target="_blank">YOUNG, R. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <!-- / .uu-container -->
# <div class="row text-center">
# <a href="seating_availability.html?subject=CS">Seating availability for all CS classes</a>
# </div>
# <!-- ************** END MAIN CONTENT AREA ************** -->
# <footer class="uu-footer" role="contentinfo">
# <div class="uu-container">
# <div class="uu-footer-content">
# <div class="uu-footer-1">
# <p>
#                             Office of the Registrar<br/>
#                             201 S 1460 E RM 250N<br/>
#                             Salt Lake City, UT 84112-9056<br/>
#                             (801) 581-5808<br/>
# </p>
# <p class="elevator-button">Back to the top</p>
# <p><a href="http://www.utah.edu">© The University of Utah</a></p>
# </div>
# <div class="uu-footer-2">
# <ul>
# <li><a href="http://www.utah.edu/nondiscrimination/">Nondiscrimination &amp; Accessibility</a></li>
# <li><a href="http://www.utah.edu/disclaimer/">Disclaimer</a></li>
# <li><a href="http://www.utah.edu/privacy/">Privacy</a></li>
# <li><a href="http://www.utah.edu/contact/">Contact</a></li>
# </ul>
# </div>
# <div class="uu-footer-3">
# </div>
# <div class="uu-footer-4">
# <div class="footer-logo">
# <h2>
# <a href="http://imagineu.utah.edu/"><img alt="Imagine U: The University of Utah" src="//templates.utah.edu/apps/v1/_images/template/imagine_u.png"/></a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.floatThead._.js"></script>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.floatThead.js"></script>
# <script>
#         //<![CDATA[
#             if($(window).width() >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }
#             $(window).resize(function(){
#                 if($(window).width() >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }else{
#                    $('table.main-table').floatThead('reflow');
#                 }
#                    if(screen.width >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }else {
#                     $('table.main-table').floatThead('reflow');
#                 }
#             });
#
#          // ]]>
#
#         </script>
# <script src="//templates.utah.edu/apps/v1/_js/vendor/bootstrap.min.js"></script>
# <script src="//templates.utah.edu/apps/v1/_js/main.js"></script>
# </table></div></div></div></div></main></section></body></html>

# %% [markdown]
# Now, let's analyze this html in the inspector.

# %% [markdown]
# ![Class Site Inspected](class.png)
#
# The data is stored in a table that has the ID `classDetailsTable`. Let's extract that table:

# %%
# now we check out an example to see what a good characteristic is
class_table = class_soup.find(id="classDetailsTable")
print(class_table)
# Out:
# <table class="table table-bordered table-striped main-table class-details-table" id="classDetailsTable">
# <thead><tr>
# <th class="nowrap">Class #</th>
# <th>Subject <span class="glyphs"></span></th>
# <th class="nowrap">Cat. #</th>
# <th>Sec.</th>
# <th>Component</th>
# <th>Units</th>
# <th>Title</th>
# <th class="nowrap">Days/Time &amp; Session</th>
# <th>Location</th>
# <th><a href="#">Class Attrs</a></th>
# <th>Instructor</th>
# <th><a href="#">Feed back</a></th>
# <th>Pre Req</th>
# <th>Fees</th>
# </tr>
# </thead>
# <tr class="odd">
# <td><a name="6634"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1001&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1001">1001</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  1.5</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/6634/CS_1000_Syllabus_Spring_2019.pdf">Eng Computing MATLAB</a>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>03:00PM-04:20PM</span> <br/>
# </p>
# <p>
# <a href="http://registrar.utah.edu/academic-calendars/spring2019.php" target="_blank">Session: First Half</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L110</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0080076/teaching/index.hml" target="_blank">DE ST GERMAIN, J. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7140" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 6 belong to this lecture. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="6635"></a><span>6635</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1001&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1001">1001</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Eng Computing MATLAB</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# <p>
# <a href="http://registrar.utah.edu/academic-calendars/spring2019.php" target="_blank">Session: First Half</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L226</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0080076/teaching/index.hml" target="_blank">DE ST GERMAIN, J. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7140" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8267"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 -8 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This course may be waived by passing a proficiency test. See <a href="http://www.cs.utah.edu/placement" target="_blank">http://www.cs.utah.edu/placement</a> for details. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="8268"></a><span>8268</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8269"></a><span>8269</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="8270"></a><span>8270</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8266"></a><span>8266</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10330"></a><span>10330</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="11186"></a><span>11186</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6645"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="https://utah.instructure.com/courses/542520/assignments/syllabus">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=GC" target="_blank">GC 1900</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 002 - 007 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This course requires a proficiency test or the required pre-requisites in order to register. Go to <a href="http://www.cs.utah.edu/placement" target="_blank">http://www.cs.utah.edu/placement</a> for the proficiency test required to waive CS 1030. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="8801"></a><span>8801</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6646"></a><span>6646</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6647"></a><span>6647</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6648"></a><span>6648</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6649"></a><span>6649</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6650"></a><span>6650</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15689"></a><span>15689</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15754"></a><span>15754</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>009</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="16563"></a><span>16563</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>010</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>05:15PM-06:05PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7911"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/7911/CS2100registrar.pdf">Discrete Structures</a>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 002-007 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="7912"></a><span>7912</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>002</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7913"></a><span>7913</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>003</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L112</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9987"></a><span>9987</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>004</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L110</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="11270"></a><span>11270</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>005</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L114</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13993"></a><span>13993</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>006</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L114</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6657"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/2420_Sp19.html">Intro Alg &amp; Data Struct</a>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>03:00PM-04:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=ASB" target="_blank">ASB 220</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 13 belong to this lecture. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="6658"></a><span>6658</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6659"></a><span>6659</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6660"></a><span>6660</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6661"></a><span>6661</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6662"></a><span>6662</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="8103"></a><span>8103</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="10570"></a><span>10570</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10640"></a><span>10640</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>009</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15745"></a><span>15745</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>010</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="15746"></a><span>15746</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>011</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="16102"></a><span>16102</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>012</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="16103"></a><span>16103</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>013</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="7231"></a><span>7231</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3011&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3011">3011</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Industry Forum</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852541/teaching/index.hml" target="_blank">VAN DER MERWE, J. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7770" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="9293"></a><span>9293</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3130&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3130">3130</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Eng Prob Stats</span>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=QI">QI</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0032913/teaching/index.hml" target="_blank">COTTER, N. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1174&amp;class_nbr=10744" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 3530 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="6663"></a><span>6663</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3200&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3200">3200</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/6663/CS3200Core-Course-Information-Form.docx">Intro Sci Comp</a>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>08:05AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L103</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0638611/teaching/index.hml" target="_blank">SHANKAR, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10906"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 5 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="10907"></a><span>10907</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>002</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10908"></a><span>10908</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>003</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="10909"></a><span>10909</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>004</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="11192"></a><span>11192</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>005</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="14156"></a><span>14156</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>006</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="17550"></a><span>17550</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>007</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6664"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3505&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3505">3505</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Software Practice II</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7171" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# ...
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="18661"></a><span>18661</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6960&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6960">6960</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Fund. of Cloud Systems</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WBB" target="_blank">WBB 617</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6007330/teaching/index.hml" target="_blank">JI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 5960 017</li>
# <li>ECE 6960 017</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="12956"></a><span>12956</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6963&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6963">6963</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~mflatt/cs6963/">Functional Programming</a>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 1460</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0176314/teaching/index.hml" target="_blank">FLATT, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6703"></a><span>6703</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7930&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7930">7930</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>SoC Colloquium</span>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>09:40AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 2250</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0237293/teaching/index.hml" target="_blank">WHITAKER, R. T.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15197"></a><span>15197</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7931&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7931">7931</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://www.cs.utah.edu/~srikumar/cs7931">Computer Vision Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>10:45AM-11:45AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3490</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6009067/teaching/index.hml" target="_blank">RAMALINGAM, S.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=17506" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="7475"></a><span>7475</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7933&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7933">7933</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Graphics Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>12:10PM-01:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002542/teaching/index.hml" target="_blank">KAVAN, L.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7298"></a><span>7298</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7934&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7934">7934</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://www.eng.utah.edu/~csl-sem/">Computer Systems Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3485</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0031750/teaching/index.hml" target="_blank">EIDE, E. N.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="10366"></a><span>10366</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7935&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7935">7935</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Natural Lang. Processing Sem.</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>11:00AM-12:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028599/teaching/index.hml" target="_blank">RILOFF, E. M.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u0929025/teaching/index.hml" target="_blank">SRIKUMAR, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15196"></a><span>15196</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7936&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7936">7936</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://pubweb.eng.utah.edu/~cs7936/">Security Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3485</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0982243/teaching/index.hml" target="_blank">DENNING, T.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8786"></a><span>8786</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7937&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7937">7937</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Arch/VLSI</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>01:30PM-02:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB RM" target="_blank">MEB RM TBA</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6009029/teaching/index.hml" target="_blank">NAZM BOJNORDI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Class meets in MEB 3383. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="7665"></a><span>7665</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7938&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7938">7938</a>
# </td>
# <td>002</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Image Analysis Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Mo</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0492366/teaching/index.hml" target="_blank">JOSHI, S.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>BIOEN 6810 001</li>
# <li>ECE 6960 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="6914"></a><span>6914</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7939&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7939">7939</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://pubweb.eng.utah.edu/~cs7939/">Robotics</a>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0029780/teaching/index.hml" target="_blank">HOLLERBACH, J. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ME EN 7960 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9105"></a><span>9105</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7941&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7941">7941</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~jeffp/teaching/cs7941.html">Data Science Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Th</span> / <span>12:15PM-01:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0684549/teaching/index.hml" target="_blank">PHILLIPS, J.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=9822" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9161"></a><span>9161</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7942&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7942">7942</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Visualization Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0632547/teaching/index.hml" target="_blank">PASCUCCI, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in WEB 3780. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="11417"></a><span>11417</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7943&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7943">7943</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Networking Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3515</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852541/teaching/index.hml" target="_blank">VAN DER MERWE, J. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15926"></a><span>15926</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7944&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7944">7944</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://qed.cs.utah.edu/classes/cs-7944-computational-narrative-seminar">Comp Narrative Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Mo</span> / <span>11:00AM-12:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3490</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6014318/teaching/index.hml" target="_blank">CARDONA-RIVERA, R.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u6006841/teaching/index.hml" target="_blank">YOUNG, R. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <!-- / .uu-container -->
# <div class="row text-center">
# <a href="seating_availability.html?subject=CS">Seating availability for all CS classes</a>
# </div>
# <!-- ************** END MAIN CONTENT AREA ************** -->
# <footer class="uu-footer" role="contentinfo">
# <div class="uu-container">
# <div class="uu-footer-content">
# <div class="uu-footer-1">
# <p>
#                             Office of the Registrar<br/>
#                             201 S 1460 E RM 250N<br/>
#                             Salt Lake City, UT 84112-9056<br/>
#                             (801) 581-5808<br/>
# </p>
# <p class="elevator-button">Back to the top</p>
# <p><a href="http://www.utah.edu">© The University of Utah</a></p>
# </div>
# <div class="uu-footer-2">
# <ul>
# <li><a href="http://www.utah.edu/nondiscrimination/">Nondiscrimination &amp; Accessibility</a></li>
# <li><a href="http://www.utah.edu/disclaimer/">Disclaimer</a></li>
# <li><a href="http://www.utah.edu/privacy/">Privacy</a></li>
# <li><a href="http://www.utah.edu/contact/">Contact</a></li>
# </ul>
# </div>
# <div class="uu-footer-3">
# </div>
# <div class="uu-footer-4">
# <div class="footer-logo">
# <h2>
# <a href="http://imagineu.utah.edu/"><img alt="Imagine U: The University of Utah" src="//templates.utah.edu/apps/v1/_images/template/imagine_u.png"/></a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.floatThead._.js"></script>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.floatThead.js"></script>
# <script>
#         //<![CDATA[
#             if($(window).width() >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }
#             $(window).resize(function(){
#                 if($(window).width() >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }else{
#                    $('table.main-table').floatThead('reflow');
#                 }
#                    if(screen.width >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }else {
#                     $('table.main-table').floatThead('reflow');
#                 }
#             });
#
#          // ]]>
#
#         </script>
# <script src="//templates.utah.edu/apps/v1/_js/vendor/bootstrap.min.js"></script>
# <script src="//templates.utah.edu/apps/v1/_js/main.js"></script>
# </table>

# %% [markdown]
# When we have a table, there is an easy way to get the data out - use the magic of Pandas data import functions. There is a sophisticated [`read_html()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html) function.
#
# Behind the scenes, this uses html5lib, which should be part of your anaconda installation, but if not, you will have to install it:
#
# ```
# conda install -c anaconda html5lib
# ```
#
# Once installed, we can pass in the table as a string:

# %%
import pandas as pd

classes = pd.read_html(str(class_table))[0]
classes.head(50)
# Out:
#                                               Class #  Subject  Cat. #  Sec.  \
# 0                                             Class #  Subject  Cat. #  Sec.
# 1                                                 NaN       CS    1001   001
# 2   Sections 2 - 6 belong to this lecture. This co...      NaN     NaN   NaN
# 3                                                6635       CS    1001   002
# 4                                                 NaN       CS    1030   001
# 5   Sections 2 -8 belong to this lecture. This cou...      NaN     NaN   NaN
# 6                                                8268       CS    1030   002
# 7                                                8269       CS    1030   003
# 8                                                8270       CS    1030   004
# 9                                                8266       CS    1030   005
# 10                                              10330       CS    1030   006
# 11                                              11186       CS    1030   008
# 12                                                NaN       CS    1410   001
# 13  Sections 002 - 007 belong to this lecture. Thi...      NaN     NaN   NaN
# 14                                               8801       CS    1410   002
# 15                                               6646       CS    1410   003
# 16                                               6647       CS    1410   004
# 17                                               6648       CS    1410   005
# 18                                               6649       CS    1410   006
# 19                                               6650       CS    1410   007
# 20                                              15689       CS    1410   008
# 21                                              15754       CS    1410   009
# 22                                              16563       CS    1410   010
# 23                                                NaN       CS    2100   001
# 24  Sections 002-007 belong to this lecture. This ...      NaN     NaN   NaN
# 25                                               7912       CS    2100   002
# 26                                               7913       CS    2100   003
# 27                                               9987       CS    2100   004
# 28                                              11270       CS    2100   005
# 29                                              13993       CS    2100   006
# 30                                                NaN       CS    2420   001
# 31  Sections 2 - 13 belong to this lecture. This c...      NaN     NaN   NaN
# 32                                               6658       CS    2420   002
# 33                                               6659       CS    2420   003
# 34                                               6660       CS    2420   004
# 35                                               6661       CS    2420   005
# 36                                               6662       CS    2420   006
# 37                                               8103       CS    2420   007
# 38                                              10570       CS    2420   008
# 39                                              10640       CS    2420   009
# 40                                              15745       CS    2420   010
# 41                      This class meets in MEB 3167.      NaN     NaN   NaN
# 42                                              15746       CS    2420   011
# 43                      This class meets in MEB 3167.      NaN     NaN   NaN
# 44                                              16102       CS    2420   012
# 45                      This class meets in MEB 3167.      NaN     NaN   NaN
# 46                                              16103       CS    2420   013
# 47                      This class meets in MEB 3167.      NaN     NaN   NaN
# 48                                               7231       CS    3011   001
# 49                                               9293       CS    3130   001
#
#      Component  Units                    Title  \
# 0    Component  Units                    Title
# 1      Lecture    1.5     Eng Computing MATLAB
# 2          NaN    NaN                      NaN
# 3   Laboratory     --     Eng Computing MATLAB
# 4      Lecture    3.0        Foundations of CS
# 5          NaN    NaN                      NaN
# 6   Laboratory     --        Foundations of CS
# 7   Laboratory     --        Foundations of CS
# 8   Laboratory     --        Foundations of CS
# 9   Laboratory     --        Foundations of CS
# 10  Laboratory     --        Foundations of CS
# 11  Laboratory     --        Foundations of CS
# 12     Lecture    4.0     Object-Oriented Prog
# 13         NaN    NaN                      NaN
# 14  Laboratory     --     Object-Oriented Prog
# 15  Laboratory     --     Object-Oriented Prog
# 16  Laboratory     --     Object-Oriented Prog
# 17  Laboratory     --     Object-Oriented Prog
# 18  Laboratory     --     Object-Oriented Prog
# 19  Laboratory     --     Object-Oriented Prog
# 20  Laboratory     --     Object-Oriented Prog
# 21  Laboratory     --     Object-Oriented Prog
# 22  Laboratory     --     Object-Oriented Prog
# 23     Lecture    3.0      Discrete Structures
# 24         NaN    NaN                      NaN
# 25  Discussion     --      Discrete Structures
# 26  Discussion     --      Discrete Structures
# 27  Discussion     --      Discrete Structures
# 28  Discussion     --      Discrete Structures
# 29  Discussion     --      Discrete Structures
# 30     Lecture    4.0  Intro Alg & Data Struct
# 31         NaN    NaN                      NaN
# 32  Laboratory     --  Intro Alg & Data Struct
# 33  Laboratory     --  Intro Alg & Data Struct
# 34  Laboratory     --  Intro Alg & Data Struct
# 35  Laboratory     --  Intro Alg & Data Struct
# 36  Laboratory     --  Intro Alg & Data Struct
# 37  Laboratory     --  Intro Alg & Data Struct
# 38  Laboratory     --  Intro Alg & Data Struct
# 39  Laboratory     --  Intro Alg & Data Struct
# 40  Laboratory     --  Intro Alg & Data Struct
# 41         NaN    NaN                      NaN
# 42  Laboratory     --  Intro Alg & Data Struct
# 43         NaN    NaN                      NaN
# 44  Laboratory     --  Intro Alg & Data Struct
# 45         NaN    NaN                      NaN
# 46  Laboratory     --  Intro Alg & Data Struct
# 47         NaN    NaN                      NaN
# 48     Lecture    1.0           Industry Forum
# 49     Lecture    3.0           Eng Prob Stats
#
#                            Days/Time & Session  Location  Class Attrs  \
# 0                          Days/Time & Session  Location  Class Attrs
# 1   MoWe / 03:00PM-04:20PM Session: First Half  WEB L110          NaN
# 2                                          NaN       NaN          NaN
# 3     Fr / 08:35AM-09:25AM Session: First Half  WEB L226          NaN
# 4                       MoWe / 02:00PM-02:50PM  WEB L101          NaN
# 5                                          NaN       NaN          NaN
# 6                       TuTh / 12:55PM-01:45PM  WEB L124          NaN
# 7                       TuTh / 02:00PM-02:50PM  WEB L124          NaN
# 8                       TuTh / 03:05PM-03:55PM  WEB L124          NaN
# 9                       TuTh / 04:10PM-05:00PM  WEB L124          NaN
# 10                      TuTh / 11:50AM-12:40PM  WEB L124          NaN
# 11                      TuTh / 10:45AM-11:35AM  WEB L124          NaN
# 12                    MoWeFr / 10:45AM-11:35AM   GC 1900          NaN
# 13                                         NaN       NaN          NaN
# 14                        Tu / 08:35AM-09:25AM  MEB 3225          NaN
# 15                        Tu / 09:40AM-10:30AM  MEB 3225          NaN
# 16                        Tu / 10:45AM-11:35AM  MEB 3225          NaN
# 17                        Tu / 11:50AM-12:40PM  MEB 3225          NaN
# 18                        Tu / 12:55PM-01:45PM  MEB 3225          NaN
# 19                        Tu / 02:00PM-02:50PM  MEB 3225          NaN
# 20                        Tu / 03:05PM-03:55PM  MEB 3225          NaN
# 21                        Tu / 04:10PM-05:00PM  MEB 3225          NaN
# 22                        Tu / 05:15PM-06:05PM  MEB 3225          NaN
# 23                      TuTh / 12:25PM-01:45PM  WEB L104          NaN
# 24                                         NaN       NaN          NaN
# 25                        Fr / 10:45AM-11:35AM  WEB L101          NaN
# 26                        Fr / 11:50AM-12:40PM  WEB L112          NaN
# 27                        Fr / 09:40AM-10:30AM  WEB L110          NaN
# 28                        Fr / 12:55PM-01:45PM  WEB L114          NaN
# 29                        Fr / 02:00PM-02:50PM  WEB L114          NaN
# 30                      MoWe / 03:00PM-04:20PM   ASB 220          NaN
# 31                                         NaN       NaN          NaN
# 32                        Fr / 08:35AM-09:25AM  MEB 3225          NaN
# 33                        Fr / 09:40AM-10:30AM  MEB 3225          NaN
# 34                        Fr / 10:45AM-11:35AM  MEB 3225          NaN
# 35                        Fr / 11:50AM-12:40PM  MEB 3225          NaN
# 36                        Fr / 12:55PM-01:45PM  MEB 3225          NaN
# 37                        Fr / 02:00PM-02:50PM  MEB 3225          NaN
# 38                        Fr / 03:05PM-03:55PM  MEB 3225          NaN
# 39                        Fr / 04:10PM-05:00PM  MEB 3225          NaN
# 40                        Fr / 09:40AM-10:30AM     TBA .          NaN
# 41                                         NaN       NaN          NaN
# 42                        Fr / 10:45AM-11:35AM     TBA .          NaN
# 43                                         NaN       NaN          NaN
# 44                        Fr / 12:55PM-01:45PM     TBA .          NaN
# 45                                         NaN       NaN          NaN
# 46                        Fr / 11:50AM-12:40PM     TBA .          NaN
# 47                                         NaN       NaN          NaN
# 48                        Fr / 10:45AM-11:35AM  WEB L104          NaN
# 49                    MoWeFr / 09:40AM-10:30AM  WEB L104           QI
#
#               Instructor  Feed back  Pre Req  Fees
# 0             Instructor  Feed back  Pre Req  Fees
# 1   DE ST GERMAIN, J. D.       View        Y   NaN
# 2                    NaN        NaN      NaN   NaN
# 3   DE ST GERMAIN, J. D.       View        Y   NaN
# 4          JENSEN, P. A.       View        Y   NaN
# 5                    NaN        NaN      NaN   NaN
# 6          JENSEN, P. A.       View        Y   NaN
# 7          JENSEN, P. A.       View        Y   NaN
# 8          JENSEN, P. A.       View        Y   NaN
# 9          JENSEN, P. A.       View        Y   NaN
# 10         JENSEN, P. A.       View        Y   NaN
# 11         JENSEN, P. A.       View        Y   NaN
# 12        JOHNSON, D. E.       View        Y   NaN
# 13                   NaN        NaN      NaN   NaN
# 14        JOHNSON, D. E.       View        Y   NaN
# 15        JOHNSON, D. E.       View        Y   NaN
# 16        JOHNSON, D. E.       View        Y   NaN
# 17        JOHNSON, D. E.       View        Y   NaN
# 18        JOHNSON, D. E.       View        Y   NaN
# 19        JOHNSON, D. E.       View        Y   NaN
# 20        JOHNSON, D. E.       View        Y   NaN
# 21        JOHNSON, D. E.       View        Y   NaN
# 22        JOHNSON, D. E.       View        Y   NaN
# 23             COHEN, E.       View        Y   NaN
# 24                   NaN        NaN      NaN   NaN
# 25             COHEN, E.       View        Y   NaN
# 26             COHEN, E.       View        Y   NaN
# 27             COHEN, E.       View        Y   NaN
# 28             COHEN, E.       View        Y   NaN
# 29             COHEN, E.       View        Y   NaN
# 30            PARKER, D.        NaN        Y   NaN
# 31                   NaN        NaN      NaN   NaN
# 32            PARKER, D.        NaN        Y   NaN
# 33            PARKER, D.        NaN        Y   NaN
# 34            PARKER, D.        NaN        Y   NaN
# 35            PARKER, D.        NaN        Y   NaN
# 36            PARKER, D.        NaN        Y   NaN
# 37            PARKER, D.        NaN        Y   NaN
# 38            PARKER, D.        NaN        Y   NaN
# 39            PARKER, D.        NaN        Y   NaN
# 40            PARKER, D.        NaN        Y   NaN
# 41                   NaN        NaN      NaN   NaN
# 42            PARKER, D.        NaN        Y   NaN
# 43                   NaN        NaN      NaN   NaN
# 44            PARKER, D.        NaN        Y   NaN
# 45                   NaN        NaN      NaN   NaN
# 46            PARKER, D.        NaN        Y   NaN
# 47                   NaN        NaN      NaN   NaN
# 48  VAN DER MERWE, J. E.       View        Y   NaN
# 49         COTTER, N. E.       View        Y   NaN

# %% [markdown]
# This is a table, but it looks like the definition of dirty data. There are extra rows we want to get rid of. It looks like the proper rows have a defined value in the `Sec.` field, so we'll filter out rows that don't have values there.

# %%
mask = pd.notnull(classes["Sec."])
classes[mask]
# Out:
#      Class #  Subject  Cat. #  Sec.       Component  Units  \
# 0    Class #  Subject  Cat. #  Sec.       Component  Units
# 1        NaN       CS    1001   001         Lecture    1.5
# 3       6635       CS    1001   002      Laboratory     --
# 4        NaN       CS    1030   001         Lecture    3.0
# 6       8268       CS    1030   002      Laboratory     --
# 7       8269       CS    1030   003      Laboratory     --
# 8       8270       CS    1030   004      Laboratory     --
# 9       8266       CS    1030   005      Laboratory     --
# 10     10330       CS    1030   006      Laboratory     --
# 11     11186       CS    1030   008      Laboratory     --
# 12       NaN       CS    1410   001         Lecture    4.0
# 14      8801       CS    1410   002      Laboratory     --
# 15      6646       CS    1410   003      Laboratory     --
# 16      6647       CS    1410   004      Laboratory     --
# 17      6648       CS    1410   005      Laboratory     --
# 18      6649       CS    1410   006      Laboratory     --
# 19      6650       CS    1410   007      Laboratory     --
# 20     15689       CS    1410   008      Laboratory     --
# 21     15754       CS    1410   009      Laboratory     --
# 22     16563       CS    1410   010      Laboratory     --
# 23       NaN       CS    2100   001         Lecture    3.0
# 25      7912       CS    2100   002      Discussion     --
# 26      7913       CS    2100   003      Discussion     --
# 27      9987       CS    2100   004      Discussion     --
# 28     11270       CS    2100   005      Discussion     --
# 29     13993       CS    2100   006      Discussion     --
# 30       NaN       CS    2420   001         Lecture    4.0
# 32      6658       CS    2420   002      Laboratory     --
# 33      6659       CS    2420   003      Laboratory     --
# 34      6660       CS    2420   004      Laboratory     --
# ..       ...      ...     ...   ...             ...    ...
# 131     6704       CS    6300   001         Lecture    3.0
# 132     8961       CS    6320   001         Lecture    3.0
# 133     9411       CS    6330   001         Lecture    3.0
# 135    15922       CS    6350   001         Lecture    3.0
# 137    19055       CS    6360   001         Lecture    3.0
# 139     9093       CS    6460   001         Lecture    3.0
# 141    10913       CS    6610   001         Lecture    3.0
# 143    15210       CS    6635   001         Lecture    3.0
# 145    17276       CS    6660   001         Lecture    3.0
# 146    17682       CS    6740   001         Lecture    3.0
# 148      NaN       CS    6780   001         Lecture    4.0
# 150     9408       CS    6780   002      Laboratory     --
# 152     9410       CS    6780   004      Laboratory     --
# 154    11216       CS    6780   005      Laboratory     --
# 156    17274       CS    6956   001  Special Topics    3.0
# 157    18661       CS    6960   001  Special Topics    3.0
# 159    12956       CS    6963   001  Special Topics    3.0
# 160     6703       CS    7930   001         Seminar    1.0
# 161    15197       CS    7931   001         Seminar    1.0
# 162     7475       CS    7933   001         Seminar    1.0
# 163     7298       CS    7934   001         Seminar    1.0
# 164    10366       CS    7935   001         Seminar    1.0
# 165    15196       CS    7936   001         Seminar    1.0
# 166     8786       CS    7937   001         Seminar    1.0
# 168     7665       CS    7938   002         Seminar    1.0
# 170     6914       CS    7939   001         Seminar    1.0
# 172     9105       CS    7941   001         Seminar    1.0
# 173     9161       CS    7942   001         Seminar    1.0
# 175    11417       CS    7943   001         Seminar    1.0
# 176    15926       CS    7944   001         Seminar    1.0
#
#                              Title  \
# 0                            Title
# 1             Eng Computing MATLAB
# 3             Eng Computing MATLAB
# 4                Foundations of CS
# 6                Foundations of CS
# 7                Foundations of CS
# 8                Foundations of CS
# 9                Foundations of CS
# 10               Foundations of CS
# 11               Foundations of CS
# 12            Object-Oriented Prog
# 14            Object-Oriented Prog
# 15            Object-Oriented Prog
# 16            Object-Oriented Prog
# 17            Object-Oriented Prog
# 18            Object-Oriented Prog
# 19            Object-Oriented Prog
# 20            Object-Oriented Prog
# 21            Object-Oriented Prog
# 22            Object-Oriented Prog
# 23             Discrete Structures
# 25             Discrete Structures
# 26             Discrete Structures
# 27             Discrete Structures
# 28             Discrete Structures
# 29             Discrete Structures
# 30         Intro Alg & Data Struct
# 32         Intro Alg & Data Struct
# 33         Intro Alg & Data Struct
# 34         Intro Alg & Data Struct
# ..                             ...
# 131        Artificial Intelligence
# 132                Computer Vision
# 133         Intro to Robot Control
# 135               Machine Learning
# 137                Virtual Reality
# 139              Operating Systems
# 141         Interactive Comp Graph
# 143        Vis for Scientific Data
# 145        Physics-based Animation
# 146        CAD of Digital Circuits
# 148               Embed Sys Design
# 150               Embed Sys Design
# 152               Embed Sys Design
# 154               Embed Sys Design
# 156          Deep Learning for NLP
# 157         Fund. of Cloud Systems
# 159         Functional Programming
# 160                 SoC Colloquium
# 161        Computer Vision Seminar
# 162               Graphics Seminar
# 163       Computer Systems Seminar
# 164  Natural Lang. Processing Sem.
# 165               Security Seminar
# 166                      Arch/VLSI
# 168         Image Analysis Seminar
# 170                       Robotics
# 172           Data Science Seminar
# 173          Visualization Seminar
# 175             Networking Seminar
# 176         Comp Narrative Seminar
#
#                             Days/Time & Session    Location  Class Attrs  \
# 0                           Days/Time & Session    Location  Class Attrs
# 1    MoWe / 03:00PM-04:20PM Session: First Half    WEB L110          NaN
# 3      Fr / 08:35AM-09:25AM Session: First Half    WEB L226          NaN
# 4                        MoWe / 02:00PM-02:50PM    WEB L101          NaN
# 6                        TuTh / 12:55PM-01:45PM    WEB L124          NaN
# 7                        TuTh / 02:00PM-02:50PM    WEB L124          NaN
# 8                        TuTh / 03:05PM-03:55PM    WEB L124          NaN
# 9                        TuTh / 04:10PM-05:00PM    WEB L124          NaN
# 10                       TuTh / 11:50AM-12:40PM    WEB L124          NaN
# 11                       TuTh / 10:45AM-11:35AM    WEB L124          NaN
# 12                     MoWeFr / 10:45AM-11:35AM     GC 1900          NaN
# 14                         Tu / 08:35AM-09:25AM    MEB 3225          NaN
# 15                         Tu / 09:40AM-10:30AM    MEB 3225          NaN
# 16                         Tu / 10:45AM-11:35AM    MEB 3225          NaN
# 17                         Tu / 11:50AM-12:40PM    MEB 3225          NaN
# 18                         Tu / 12:55PM-01:45PM    MEB 3225          NaN
# 19                         Tu / 02:00PM-02:50PM    MEB 3225          NaN
# 20                         Tu / 03:05PM-03:55PM    MEB 3225          NaN
# 21                         Tu / 04:10PM-05:00PM    MEB 3225          NaN
# 22                         Tu / 05:15PM-06:05PM    MEB 3225          NaN
# 23                       TuTh / 12:25PM-01:45PM    WEB L104          NaN
# 25                         Fr / 10:45AM-11:35AM    WEB L101          NaN
# 26                         Fr / 11:50AM-12:40PM    WEB L112          NaN
# 27                         Fr / 09:40AM-10:30AM    WEB L110          NaN
# 28                         Fr / 12:55PM-01:45PM    WEB L114          NaN
# 29                         Fr / 02:00PM-02:50PM    WEB L114          NaN
# 30                       MoWe / 03:00PM-04:20PM     ASB 220          NaN
# 32                         Fr / 08:35AM-09:25AM    MEB 3225          NaN
# 33                         Fr / 09:40AM-10:30AM    MEB 3225          NaN
# 34                         Fr / 10:45AM-11:35AM    MEB 3225          NaN
# ..                                          ...         ...          ...
# 131                      TuTh / 12:25PM-01:45PM    WEB 2230          NaN
# 132                      MoWe / 01:25PM-02:45PM    WEB L114          NaN
# 133                      MoWe / 03:00PM-04:20PM    WEB 1250          NaN
# 135                      MoWe / 04:35PM-05:55PM    WEB 1250          NaN
# 137                      MoWe / 04:35PM-05:55PM    WEB L226          NaN
# 139                      TuTh / 09:10AM-10:30AM    WEB L101          NaN
# 141                      TuTh / 02:00PM-03:20PM    WEB L110          NaN
# 143                      TuTh / 12:25PM-01:45PM    WEB L105          NaN
# 145                      TuTh / 10:45AM-11:35AM    WEB L126          NaN
# 146                    MoWeFr / 11:50AM-12:40PM     LCB 215          NaN
# 148                      TuTh / 12:25PM-01:45PM    WEB 1250          NaN
# 150                        We / 07:30AM-10:30AM    MEB 2555          NaN
# 152                        Fr / 07:30AM-10:30AM    MEB 2555          NaN
# 154                        Mo / 03:05PM-06:05PM    MEB 2555          NaN
# 156                      MoWe / 11:50AM-01:10PM     GC 4020          NaN
# 157                      TuTh / 02:00PM-03:20PM     WBB 617          NaN
# 159                      TuTh / 12:25PM-01:45PM    WEB 1460          NaN
# 160                    MoWeFr / 09:40AM-11:35AM    WEB 2250          NaN
# 161                        Tu / 10:45AM-11:45AM    MEB 3490          NaN
# 162                        Tu / 12:10PM-01:55PM    MEB 3147          NaN
# 163                        Fr / 02:00PM-03:30PM    MEB 3485          NaN
# 164                        Tu / 11:00AM-12:00PM    MEB 3147          NaN
# 165                        We / 12:00PM-01:00PM    MEB 3485          NaN
# 166                        Fr / 01:30PM-02:30PM  MEB RM TBA          NaN
# 168                        Mo / 12:00PM-01:00PM    WEB 3760          NaN
# 170                        Tu / 02:00PM-02:50PM    MEB 3147          NaN
# 172                        Th / 12:15PM-01:30PM    MEB 3147          NaN
# 173                        We / 12:00PM-01:00PM       TBA .          NaN
# 175                        Fr / 02:00PM-03:30PM    MEB 3515          NaN
# 176                        Mo / 11:00AM-12:00PM    MEB 3490          NaN
#
#                           Instructor  Feed back  Pre Req    Fees
# 0                         Instructor  Feed back  Pre Req    Fees
# 1               DE ST GERMAIN, J. D.       View        Y     NaN
# 3               DE ST GERMAIN, J. D.       View        Y     NaN
# 4                      JENSEN, P. A.       View        Y     NaN
# 6                      JENSEN, P. A.       View        Y     NaN
# 7                      JENSEN, P. A.       View        Y     NaN
# 8                      JENSEN, P. A.       View        Y     NaN
# 9                      JENSEN, P. A.       View        Y     NaN
# 10                     JENSEN, P. A.       View        Y     NaN
# 11                     JENSEN, P. A.       View        Y     NaN
# 12                    JOHNSON, D. E.       View        Y     NaN
# 14                    JOHNSON, D. E.       View        Y     NaN
# 15                    JOHNSON, D. E.       View        Y     NaN
# 16                    JOHNSON, D. E.       View        Y     NaN
# 17                    JOHNSON, D. E.       View        Y     NaN
# 18                    JOHNSON, D. E.       View        Y     NaN
# 19                    JOHNSON, D. E.       View        Y     NaN
# 20                    JOHNSON, D. E.       View        Y     NaN
# 21                    JOHNSON, D. E.       View        Y     NaN
# 22                    JOHNSON, D. E.       View        Y     NaN
# 23                         COHEN, E.       View        Y     NaN
# 25                         COHEN, E.       View        Y     NaN
# 26                         COHEN, E.       View        Y     NaN
# 27                         COHEN, E.       View        Y     NaN
# 28                         COHEN, E.       View        Y     NaN
# 29                         COHEN, E.       View        Y     NaN
# 30                        PARKER, D.        NaN        Y     NaN
# 32                        PARKER, D.        NaN        Y     NaN
# 33                        PARKER, D.        NaN        Y     NaN
# 34                        PARKER, D.        NaN        Y     NaN
# ..                               ...        ...      ...     ...
# 131                HOLLERBACH, J. M.       View        Y     NaN
# 132                   RAMALINGAM, S.       View        Y     NaN
# 133                   MASCARO, S. A.        NaN        Y  $40.00
# 135                          ZHE, S.       View        Y     NaN
# 137               CARDONA-RIVERA, R.        NaN        Y     NaN
# 139                     STUTSMAN, R.       View        Y     NaN
# 141                       YUKSEL, C.       View        Y     NaN
# 143                   JOHNSON, C. R.       View      NaN     NaN
# 145                        KAVAN, L.       View      NaN     NaN
# 146                        KALLA, P.        NaN        Y     NaN
# 148                GAILLARDON, P. J.        NaN        Y     NaN
# 150                GAILLARDON, P. J.        NaN        Y  $35.00
# 152                GAILLARDON, P. J.        NaN        Y  $35.00
# 154                GAILLARDON, P. J.        NaN        Y  $35.00
# 156                     SRIKUMAR, V.        NaN      NaN     NaN
# 157                           JI, M.        NaN      NaN     NaN
# 159                        FLATT, M.        NaN        Y     NaN
# 160                  WHITAKER, R. T.        NaN        Y     NaN
# 161                   RAMALINGAM, S.       View        Y     NaN
# 162                        KAVAN, L.        NaN        Y     NaN
# 163                      EIDE, E. N.        NaN        Y     NaN
# 164       RILOFF, E. M. SRIKUMAR, V.        NaN        Y     NaN
# 165                      DENNING, T.        NaN        Y     NaN
# 166                NAZM BOJNORDI, M.        NaN        Y     NaN
# 168                        JOSHI, S.        NaN        Y     NaN
# 170                HOLLERBACH, J. M.        NaN        Y     NaN
# 172                     PHILLIPS, J.       View        Y     NaN
# 173                     PASCUCCI, V.        NaN        Y     NaN
# 175             VAN DER MERWE, J. E.        NaN        Y     NaN
# 176  CARDONA-RIVERA, R. YOUNG, R. M.        NaN        Y     NaN
#
# [126 rows x 14 columns]

# %% [markdown]
# This looks better. But things like object oriented programming have many entries for each section. We'll filter to only contain lectures, seminars or special topic lectures.

# %%
classes = classes[(classes["Component"] == "Lecture") | (classes["Component"] == "Seminar") | (classes["Component"] == "Special Topics")]
classes
# Out:
#     Class # Subject Cat. # Sec.       Component Units  \
# 1       NaN      CS   1001  001         Lecture   1.5
# 4       NaN      CS   1030  001         Lecture   3.0
# 12      NaN      CS   1410  001         Lecture   4.0
# 23      NaN      CS   2100  001         Lecture   3.0
# 30      NaN      CS   2420  001         Lecture   4.0
# 48     7231      CS   3011  001         Lecture   1.0
# 49     9293      CS   3130  001         Lecture   3.0
# 51     6663      CS   3200  001         Lecture   3.0
# 52      NaN      CS   3500  001         Lecture   4.0
# 60      NaN      CS   3505  001         Lecture   3.0
# 67      NaN      CS   3700  001         Lecture   4.0
# 71    10911      CS   3810  001         Lecture   4.0
# 73     6691      CS   3992  001         Seminar   3.0
# 75    11876      CS   4000  001         Lecture   3.0
# 78     6698      CS   4150  001         Lecture   3.0
# 79    17279      CS   4300  001         Lecture   3.0
# 80      NaN      CS   4400  001         Lecture   4.0
# 86    15211      CS   4440  001         Lecture   3.0
# 87    15216      CS   4470  001         Lecture   3.0
# 88     7915      CS   4480  001         Lecture   3.0
# 89     6692      CS   4500  001         Lecture   3.0
# 90    12954      CS   4530  001         Lecture   3.0
# 91    12955      CS   4530  002         Lecture   3.0
# 92    18041      CS   5100  001         Lecture   3.0
# 94    10364      CS   5140  001         Lecture   3.0
# 96    15921      CS   5350  001         Lecture   3.0
# 98     8966      CS   5460  001         Lecture   3.0
# 100    7820      CS   5530  001         Lecture   3.0
# 101   10912      CS   5610  001         Lecture   3.0
# 103   15205      CS   5635  001         Lecture   3.0
# ..      ...     ...    ...  ...             ...   ...
# 128   17273      CS   6150  001         Lecture   3.0
# 129   17277      CS   6170  001         Lecture   3.0
# 130   15200      CS   6235  001         Lecture   3.0
# 131    6704      CS   6300  001         Lecture   3.0
# 132    8961      CS   6320  001         Lecture   3.0
# 133    9411      CS   6330  001         Lecture   3.0
# 135   15922      CS   6350  001         Lecture   3.0
# 137   19055      CS   6360  001         Lecture   3.0
# 139    9093      CS   6460  001         Lecture   3.0
# 141   10913      CS   6610  001         Lecture   3.0
# 143   15210      CS   6635  001         Lecture   3.0
# 145   17276      CS   6660  001         Lecture   3.0
# 146   17682      CS   6740  001         Lecture   3.0
# 148     NaN      CS   6780  001         Lecture   4.0
# 156   17274      CS   6956  001  Special Topics   3.0
# 157   18661      CS   6960  001  Special Topics   3.0
# 159   12956      CS   6963  001  Special Topics   3.0
# 160    6703      CS   7930  001         Seminar   1.0
# 161   15197      CS   7931  001         Seminar   1.0
# 162    7475      CS   7933  001         Seminar   1.0
# 163    7298      CS   7934  001         Seminar   1.0
# 164   10366      CS   7935  001         Seminar   1.0
# 165   15196      CS   7936  001         Seminar   1.0
# 166    8786      CS   7937  001         Seminar   1.0
# 168    7665      CS   7938  002         Seminar   1.0
# 170    6914      CS   7939  001         Seminar   1.0
# 172    9105      CS   7941  001         Seminar   1.0
# 173    9161      CS   7942  001         Seminar   1.0
# 175   11417      CS   7943  001         Seminar   1.0
# 176   15926      CS   7944  001         Seminar   1.0
#
#                              Title  \
# 1             Eng Computing MATLAB
# 4                Foundations of CS
# 12            Object-Oriented Prog
# 23             Discrete Structures
# 30         Intro Alg & Data Struct
# 48                  Industry Forum
# 49                  Eng Prob Stats
# 51                  Intro Sci Comp
# 52               Software Practice
# 60            Software Practice II
# 67           Digital System Design
# 71           Computer Organization
# 73          Pre-Thesis/Clinic/Proj
# 75          Senior Capstone Design
# 78                      Algorithms
# 79         Artificial Intelligence
# 80                Computer Systems
# 86               Computer Security
# 87                       Compilers
# 88               Computer Networks
# 89         Senior Capstone Project
# 90          Mobile App Programming
# 91          Mobile App Programming
# 92           Theory of Computation
# 94                     Data Mining
# 96                Machine Learning
# 98               Operating Systems
# 100               Database Systems
# 101         Interactive Comp Graph
# 103        Vis for Scientific Data
# ..                             ...
# 128            Advanced Algorithms
# 129         Computational Topology
# 130        Parallel Prog Many-Core
# 131        Artificial Intelligence
# 132                Computer Vision
# 133         Intro to Robot Control
# 135               Machine Learning
# 137                Virtual Reality
# 139              Operating Systems
# 141         Interactive Comp Graph
# 143        Vis for Scientific Data
# 145        Physics-based Animation
# 146        CAD of Digital Circuits
# 148               Embed Sys Design
# 156          Deep Learning for NLP
# 157         Fund. of Cloud Systems
# 159         Functional Programming
# 160                 SoC Colloquium
# 161        Computer Vision Seminar
# 162               Graphics Seminar
# 163       Computer Systems Seminar
# 164  Natural Lang. Processing Sem.
# 165               Security Seminar
# 166                      Arch/VLSI
# 168         Image Analysis Seminar
# 170                       Robotics
# 172           Data Science Seminar
# 173          Visualization Seminar
# 175             Networking Seminar
# 176         Comp Narrative Seminar
#
#                             Days/Time & Session    Location Class Attrs  \
# 1    MoWe / 03:00PM-04:20PM Session: First Half    WEB L110         NaN
# 4                        MoWe / 02:00PM-02:50PM    WEB L101         NaN
# 12                     MoWeFr / 10:45AM-11:35AM     GC 1900         NaN
# 23                       TuTh / 12:25PM-01:45PM    WEB L104         NaN
# 30                       MoWe / 03:00PM-04:20PM     ASB 220         NaN
# 48                         Fr / 10:45AM-11:35AM    WEB L104         NaN
# 49                     MoWeFr / 09:40AM-10:30AM    WEB L104          QI
# 51                       MoWe / 08:05AM-09:25AM    WEB L103         NaN
# 52                       TuTh / 02:00PM-03:20PM    WEB L104         NaN
# 60                       TuTh / 02:00PM-03:20PM    WEB L101         NaN
# 67                       TuTh / 12:25PM-01:45PM    WEB 1230          QI
# 71                       TuTh / 09:10AM-10:30AM    WEB L104          QI
# 73                       TuTh / 10:45AM-12:05PM    WEB L112         NaN
# 75                     MoWeFr / 10:45AM-11:35AM    WEB 1230         NaN
# 78                       TuTh / 10:45AM-12:05PM    WEB L101          QI
# 79                       TuTh / 10:45AM-12:05PM    WEB L103         NaN
# 80                       MoWe / 03:00PM-04:20PM    WEB L105          QI
# 86                       TuTh / 12:25PM-01:45PM    WEB L102         NaN
# 87                       TuTh / 02:00PM-03:20PM    WEB 2230         NaN
# 88                       MoWe / 01:25PM-02:45PM    WEB L105         NaN
# 89                       TuTh / 03:40PM-05:00PM    WEB 2230         NaN
# 90                       MoWe / 06:00PM-07:20PM   M LI 1120         NaN
# 91                       MoWe / 04:35PM-05:55PM   M LI 1120         NaN
# 92                       MoWe / 01:25PM-02:45PM    WEB L122         NaN
# 94                       MoWe / 03:00PM-04:20PM    WEB L104         NaN
# 96                       MoWe / 04:35PM-05:55PM    WEB 1250         NaN
# 98                       TuTh / 09:10AM-10:30AM    WEB L101         NaN
# 100                      MoWe / 11:50AM-01:10PM    MEK 3550         NaN
# 101                      TuTh / 02:00PM-03:20PM    WEB L110         NaN
# 103                      TuTh / 12:25PM-01:45PM    WEB L105         NaN
# ..                                          ...         ...         ...
# 128                    MoWeFr / 10:45AM-11:35AM    WEB L114         NaN
# 129                      TuTh / 09:10AM-10:30AM    WEB L120         NaN
# 130                      TuTh / 03:40PM-05:00PM    WEB 1250         NaN
# 131                      TuTh / 12:25PM-01:45PM    WEB 2230         NaN
# 132                      MoWe / 01:25PM-02:45PM    WEB L114         NaN
# 133                      MoWe / 03:00PM-04:20PM    WEB 1250         NaN
# 135                      MoWe / 04:35PM-05:55PM    WEB 1250         NaN
# 137                      MoWe / 04:35PM-05:55PM    WEB L226         NaN
# 139                      TuTh / 09:10AM-10:30AM    WEB L101         NaN
# 141                      TuTh / 02:00PM-03:20PM    WEB L110         NaN
# 143                      TuTh / 12:25PM-01:45PM    WEB L105         NaN
# 145                      TuTh / 10:45AM-11:35AM    WEB L126         NaN
# 146                    MoWeFr / 11:50AM-12:40PM     LCB 215         NaN
# 148                      TuTh / 12:25PM-01:45PM    WEB 1250         NaN
# 156                      MoWe / 11:50AM-01:10PM     GC 4020         NaN
# 157                      TuTh / 02:00PM-03:20PM     WBB 617         NaN
# 159                      TuTh / 12:25PM-01:45PM    WEB 1460         NaN
# 160                    MoWeFr / 09:40AM-11:35AM    WEB 2250         NaN
# 161                        Tu / 10:45AM-11:45AM    MEB 3490         NaN
# 162                        Tu / 12:10PM-01:55PM    MEB 3147         NaN
# 163                        Fr / 02:00PM-03:30PM    MEB 3485         NaN
# 164                        Tu / 11:00AM-12:00PM    MEB 3147         NaN
# 165                        We / 12:00PM-01:00PM    MEB 3485         NaN
# 166                        Fr / 01:30PM-02:30PM  MEB RM TBA         NaN
# 168                        Mo / 12:00PM-01:00PM    WEB 3760         NaN
# 170                        Tu / 02:00PM-02:50PM    MEB 3147         NaN
# 172                        Th / 12:15PM-01:30PM    MEB 3147         NaN
# 173                        We / 12:00PM-01:00PM       TBA .         NaN
# 175                        Fr / 02:00PM-03:30PM    MEB 3515         NaN
# 176                        Mo / 11:00AM-12:00PM    MEB 3490         NaN
#
#                              Instructor Feed back Pre Req    Fees
# 1                  DE ST GERMAIN, J. D.      View       Y     NaN
# 4                         JENSEN, P. A.      View       Y     NaN
# 12                       JOHNSON, D. E.      View       Y     NaN
# 23                            COHEN, E.      View       Y     NaN
# 30                           PARKER, D.       NaN       Y     NaN
# 48                 VAN DER MERWE, J. E.      View       Y     NaN
# 49                        COTTER, N. E.      View       Y     NaN
# 51                          SHANKAR, V.       NaN       Y     NaN
# 52                       ZACHARY, J. L.      View       Y     NaN
# 60                        JENSEN, P. A.      View       Y     NaN
# 67                         MYERS, C. J.       NaN       Y  $60.00
# 71                    NAZM BOJNORDI, M.       NaN       Y     NaN
# 73                      BRUNVAND, E. L.      View       Y     NaN
# 75   DE ST GERMAIN, H. J. ZIEMEK, T. R.      View       Y     NaN
# 78                       ZACHARY, J. L.      View       Y     NaN
# 79                          HERMANS, T.       NaN       Y     NaN
# 80                         KOPTA, D. M.      View       Y     NaN
# 86                          DENNING, T.      View       Y     NaN
# 87                           PARKER, D.       NaN       Y     NaN
# 88                        KASERA, S. K.       NaN       Y     NaN
# 89                 DE ST GERMAIN, H. J.      View       Y     NaN
# 90                        STOKER, M. L.      View       Y     NaN
# 91                        STOKER, M. L.      View       Y     NaN
# 92                   GOPALAKRISHNAN, G.       NaN       Y     NaN
# 94                         PHILLIPS, J.      View       Y     NaN
# 96                              ZHE, S.      View       Y     NaN
# 98                         STUTSMAN, R.      View       Y     NaN
# 100                        KOPTA, D. M.       NaN       Y     NaN
# 101                          YUKSEL, C.      View       Y     NaN
# 103                      JOHNSON, C. R.      View     NaN     NaN
# ..                                  ...       ...     ...     ...
# 128              VENKATASUBRAMANIAN, S.      View       Y     NaN
# 129                     PHILLIPS, B. W.      View       Y     NaN
# 130                         HALL, M. W.      View     NaN     NaN
# 131                   HOLLERBACH, J. M.      View       Y     NaN
# 132                      RAMALINGAM, S.      View       Y     NaN
# 133                      MASCARO, S. A.       NaN       Y  $40.00
# 135                             ZHE, S.      View       Y     NaN
# 137                  CARDONA-RIVERA, R.       NaN       Y     NaN
# 139                        STUTSMAN, R.      View       Y     NaN
# 141                          YUKSEL, C.      View       Y     NaN
# 143                      JOHNSON, C. R.      View     NaN     NaN
# 145                           KAVAN, L.      View     NaN     NaN
# 146                           KALLA, P.       NaN       Y     NaN
# 148                   GAILLARDON, P. J.       NaN       Y     NaN
# 156                        SRIKUMAR, V.       NaN     NaN     NaN
# 157                              JI, M.       NaN     NaN     NaN
# 159                           FLATT, M.       NaN       Y     NaN
# 160                     WHITAKER, R. T.       NaN       Y     NaN
# 161                      RAMALINGAM, S.      View       Y     NaN
# 162                           KAVAN, L.       NaN       Y     NaN
# 163                         EIDE, E. N.       NaN       Y     NaN
# 164          RILOFF, E. M. SRIKUMAR, V.       NaN       Y     NaN
# 165                         DENNING, T.       NaN       Y     NaN
# 166                   NAZM BOJNORDI, M.       NaN       Y     NaN
# 168                           JOSHI, S.       NaN       Y     NaN
# 170                   HOLLERBACH, J. M.       NaN       Y     NaN
# 172                        PHILLIPS, J.      View       Y     NaN
# 173                        PASCUCCI, V.       NaN       Y     NaN
# 175                VAN DER MERWE, J. E.       NaN       Y     NaN
# 176     CARDONA-RIVERA, R. YOUNG, R. M.       NaN       Y     NaN
#
# [67 rows x 14 columns]

# %% [markdown]
# So who's teaching the most Lectures/Seminars/Special Topic Courses this semester?

# %%
classes["Instructor"].value_counts()
# Out:
# GOPALAKRISHNAN, G.                    3
# PHILLIPS, J.                          3
# CARDONA-RIVERA, R.                    2
# STOKER, M. L.                         2
# STUTSMAN, R.                          2
# NAZM BOJNORDI, M.                     2
# KALLA, P.                             2
# DENNING, T.                           2
# RAMALINGAM, S.                        2
# PARKER, D.                            2
# HOLLERBACH, J. M.                     2
# VAN DER MERWE, J. E.                  2
# KOPTA, D. M.                          2
# ZACHARY, J. L.                        2
# YUKSEL, C.                            2
# ZHE, S.                               2
# KAVAN, L.                             2
# JOHNSON, C. R.                        2
# GAILLARDON, P. J.                     2
# JENSEN, P. A.                         2
# VENKATASUBRAMANIAN, S.                1
# DE ST GERMAIN, H. J. ZIEMEK, T. R.    1
# PHILLIPS, B. W.                       1
# FLATT, M.                             1
# BRUNVAND, E. L.                       1
# MASCARO, S. A.                        1
# PASCUCCI, V.                          1
# DE ST GERMAIN, J. D.                  1
# BRUNVAND, E. L. WISCHER, W.           1
# COTTER, N. E.                         1
# JOSHI, S.                             1
# HERMANS, T.                           1
# WHITAKER, R. T.                       1
# HALL, M. W.                           1
# CARDONA-RIVERA, R. YOUNG, R. M.       1
# KASERA, S. K.                         1
# JI, M.                                1
# JOHNSON, D. E.                        1
# MYERS, C. J.                          1
# EIDE, E. N.                           1
# RILOFF, E. M. SRIKUMAR, V.            1
# DE ST GERMAIN, H. J.                  1
# SHANKAR, V.                           1
# COHEN, E.                             1
# SRIKUMAR, V.                          1
# Name: Instructor, dtype: int64

# %% [markdown]
# This dataset isn't completely clean yet. There are multiple versions of classes that are not aggregated, and classes that are co-taught aren't properly separted. So for a real analysis we'd have to do more cleanup work.
#
# ### Counting Enrollment
#
# But let's look at which classes have the most students. To do this, we have to go back a couple of steps, because pandas importer didn't preserve the URLs, and the enrollment numbers are hidden just behind the next website. Here's an example for the [data science lecture](https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/sections.html?subj=COMP&catno=5360).
#
# Let's scrape the number of students from this website:

# %%
ds_enrollment_url = "https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1194/sections.html?subj=COMP&catno=5360"
with urllib.request.urlopen(ds_enrollment_url) as response:
    class_student_html = response.read()
class_student_soup = BeautifulSoup(class_student_html, 'html.parser')
# we use pandas to read the table
student_ar = pd.read_html(str(class_student_soup))
student_ar
# Out:
# [   Class # Subject  Catalog #  Section                  Title  Enrollment Cap  \
#  0    15121    COMP       5360        1  Intro to Data Science              75
#
#     Currently Enrolled  Seats Available
#  0                  58               17  ]

# %% [markdown]
# The dataframe is wrapped in an array, we can get the DF out of it:

# %%
student_df = student_ar[0]
student_df
# Out:
#    Class # Subject  Catalog #  Section                  Title  Enrollment Cap  \
# 0    15121    COMP       5360        1  Intro to Data Science              75
#
#    Currently Enrolled  Seats Available
# 0                  58               17

# %% [markdown]
# Now, we can retreive the student number:

# %%
students = student_df["Currently Enrolled"][0]
students
# Out:
# 58

# %% [markdown]
# Let's pack this all up in a function that takes the URL and returns the number:

# %%
def scrape_students(url):
    """
    Retreive the number of students from the table on the website specified in the URL
    """
    with urllib.request.urlopen(url) as response:
        class_student_html = response.read()
    class_student_soup = BeautifulSoup(class_student_html, 'html.parser')
    # we use pandas to read the table
    student_df = pd.read_html(str(class_student_soup))[0]
    students = student_df["Currently Enrolled"][0]
    return students

# %%
# test it with the datascience lecture
scrape_students(ds_enrollment_url)
# Out:
# 58

# %% [markdown]
# Now we still have to extract the URL to pass into this function and the other attributes we care about from the website. Here we'll create a tailored solution to the website – this is of course brittle and will break if the website changes (the DOM of a website isn't supposed to be a stable API). But it's the best we can do.
#
# We'll create a matrix that we'll use to initialize a dataframe. Remember that we've extracted the table into `class_table` already.

# %%
print(class_table)
# Out:
# <table class="table table-bordered table-striped main-table class-details-table" id="classDetailsTable">
# <thead><tr>
# <th class="nowrap">Class #</th>
# <th>Subject <span class="glyphs"></span></th>
# <th class="nowrap">Cat. #</th>
# <th>Sec.</th>
# <th>Component</th>
# <th>Units</th>
# <th>Title</th>
# <th class="nowrap">Days/Time &amp; Session</th>
# <th>Location</th>
# <th><a href="#">Class Attrs</a></th>
# <th>Instructor</th>
# <th><a href="#">Feed back</a></th>
# <th>Pre Req</th>
# <th>Fees</th>
# </tr>
# </thead>
# <tr class="odd">
# <td><a name="6634"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1001&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1001">1001</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  1.5</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/6634/CS_1000_Syllabus_Spring_2019.pdf">Eng Computing MATLAB</a>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>03:00PM-04:20PM</span> <br/>
# </p>
# <p>
# <a href="http://registrar.utah.edu/academic-calendars/spring2019.php" target="_blank">Session: First Half</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L110</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0080076/teaching/index.hml" target="_blank">DE ST GERMAIN, J. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7140" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 6 belong to this lecture. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="6635"></a><span>6635</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1001&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1001">1001</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Eng Computing MATLAB</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# <p>
# <a href="http://registrar.utah.edu/academic-calendars/spring2019.php" target="_blank">Session: First Half</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L226</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0080076/teaching/index.hml" target="_blank">DE ST GERMAIN, J. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7140" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8267"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 -8 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This course may be waived by passing a proficiency test. See <a href="http://www.cs.utah.edu/placement" target="_blank">http://www.cs.utah.edu/placement</a> for details. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="8268"></a><span>8268</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8269"></a><span>8269</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="8270"></a><span>8270</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8266"></a><span>8266</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10330"></a><span>10330</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="11186"></a><span>11186</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8907" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6645"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="https://utah.instructure.com/courses/542520/assignments/syllabus">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=GC" target="_blank">GC 1900</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 002 - 007 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This course requires a proficiency test or the required pre-requisites in order to register. Go to <a href="http://www.cs.utah.edu/placement" target="_blank">http://www.cs.utah.edu/placement</a> for the proficiency test required to waive CS 1030. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="8801"></a><span>8801</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6646"></a><span>6646</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6647"></a><span>6647</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6648"></a><span>6648</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6649"></a><span>6649</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6650"></a><span>6650</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15689"></a><span>15689</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15754"></a><span>15754</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>009</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="16563"></a><span>16563</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>010</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>05:15PM-06:05PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7152" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7911"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/7911/CS2100registrar.pdf">Discrete Structures</a>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 002-007 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="7912"></a><span>7912</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>002</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7913"></a><span>7913</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>003</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L112</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9987"></a><span>9987</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>004</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L110</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="11270"></a><span>11270</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>005</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L114</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13993"></a><span>13993</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>006</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L114</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028572/teaching/index.hml" target="_blank">COHEN, E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=8500" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6657"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/2420_Sp19.html">Intro Alg &amp; Data Struct</a>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>03:00PM-04:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=ASB" target="_blank">ASB 220</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 13 belong to this lecture. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="6658"></a><span>6658</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6659"></a><span>6659</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6660"></a><span>6660</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6661"></a><span>6661</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6662"></a><span>6662</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="8103"></a><span>8103</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="10570"></a><span>10570</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10640"></a><span>10640</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>009</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15745"></a><span>15745</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>010</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="15746"></a><span>15746</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>011</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="16102"></a><span>16102</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>012</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="16103"></a><span>16103</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>013</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3167. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="7231"></a><span>7231</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3011&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3011">3011</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Industry Forum</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852541/teaching/index.hml" target="_blank">VAN DER MERWE, J. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7770" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="9293"></a><span>9293</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3130&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3130">3130</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Eng Prob Stats</span>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=QI">QI</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0032913/teaching/index.hml" target="_blank">COTTER, N. E.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1174&amp;class_nbr=10744" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 3530 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="6663"></a><span>6663</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3200&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3200">3200</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="https://student.apps.utah.edu/uofu/stu/classtools/syllabus/1194/6663/CS3200Core-Course-Information-Form.docx">Intro Sci Comp</a>
# </td>
# <td class="nowrap">
# <p><span>MoWe</span> / <span>08:05AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L103</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0638611/teaching/index.hml" target="_blank">SHANKAR, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10906"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 5 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="odd">
# <td><a name="10907"></a><span>10907</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>002</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="10908"></a><span>10908</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>003</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="10909"></a><span>10909</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>004</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="11192"></a><span>11192</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>005</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="14156"></a><span>14156</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>006</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="17550"></a><span>17550</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>007</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=11872" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6664"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3505&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3505">3505</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Software Practice II</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0063547/teaching/index.hml" target="_blank">JENSEN, P. A.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=7171" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# ...
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="18661"></a><span>18661</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6960&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6960">6960</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Fund. of Cloud Systems</span>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WBB" target="_blank">WBB 617</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6007330/teaching/index.hml" target="_blank">JI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 5960 017</li>
# <li>ECE 6960 017</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="12956"></a><span>12956</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6963&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6963">6963</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~mflatt/cs6963/">Functional Programming</a>
# </td>
# <td class="nowrap">
# <p><span>TuTh</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 1460</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0176314/teaching/index.hml" target="_blank">FLATT, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6703"></a><span>6703</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7930&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7930">7930</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>SoC Colloquium</span>
# </td>
# <td class="nowrap">
# <p><span>MoWeFr</span> / <span>09:40AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 2250</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0237293/teaching/index.hml" target="_blank">WHITAKER, R. T.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15197"></a><span>15197</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7931&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7931">7931</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://www.cs.utah.edu/~srikumar/cs7931">Computer Vision Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>10:45AM-11:45AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3490</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6009067/teaching/index.hml" target="_blank">RAMALINGAM, S.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=17506" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="7475"></a><span>7475</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7933&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7933">7933</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Graphics Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>12:10PM-01:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002542/teaching/index.hml" target="_blank">KAVAN, L.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="7298"></a><span>7298</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7934&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7934">7934</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://www.eng.utah.edu/~csl-sem/">Computer Systems Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3485</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0031750/teaching/index.hml" target="_blank">EIDE, E. N.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="10366"></a><span>10366</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7935&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7935">7935</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Natural Lang. Processing Sem.</span>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>11:00AM-12:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028599/teaching/index.hml" target="_blank">RILOFF, E. M.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u0929025/teaching/index.hml" target="_blank">SRIKUMAR, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15196"></a><span>15196</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7936&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7936">7936</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://pubweb.eng.utah.edu/~cs7936/">Security Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3485</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0982243/teaching/index.hml" target="_blank">DENNING, T.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="8786"></a><span>8786</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7937&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7937">7937</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Arch/VLSI</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>01:30PM-02:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB RM" target="_blank">MEB RM TBA</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6009029/teaching/index.hml" target="_blank">NAZM BOJNORDI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Class meets in MEB 3383. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="7665"></a><span>7665</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7938&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7938">7938</a>
# </td>
# <td>002</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Image Analysis Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Mo</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0492366/teaching/index.hml" target="_blank">JOSHI, S.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>BIOEN 6810 001</li>
# <li>ECE 6960 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="6914"></a><span>6914</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7939&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7939">7939</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="https://pubweb.eng.utah.edu/~cs7939/">Robotics</a>
# </td>
# <td class="nowrap">
# <p><span>Tu</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0029780/teaching/index.hml" target="_blank">HOLLERBACH, J. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ME EN 7960 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9105"></a><span>9105</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7941&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7941">7941</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~jeffp/teaching/cs7941.html">Data Science Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Th</span> / <span>12:15PM-01:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0684549/teaching/index.hml" target="_blank">PHILLIPS, J.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1184&amp;class_nbr=9822" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9161"></a><span>9161</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7942&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7942">7942</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Visualization Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>We</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0632547/teaching/index.hml" target="_blank">PASCUCCI, V.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in WEB 3780. </span>
# </p>
# <ul>
# </ul>
# </td></tr>
# <tr class="even">
# <td><a name="11417"></a><span>11417</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7943&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7943">7943</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Networking Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>Fr</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3515</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852541/teaching/index.hml" target="_blank">VAN DER MERWE, J. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="15926"></a><span>15926</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7944&amp;subject=CS&amp;term=1194">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7944">7944</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://qed.cs.utah.edu/classes/cs-7944-computational-narrative-seminar">Comp Narrative Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>Mo</span> / <span>11:00AM-12:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3490</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=%20"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6014318/teaching/index.hml" target="_blank">CARDONA-RIVERA, R.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u6006841/teaching/index.hml" target="_blank">YOUNG, R. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <!-- / .uu-container -->
# <div class="row text-center">
# <a href="seating_availability.html?subject=CS">Seating availability for all CS classes</a>
# </div>
# <!-- ************** END MAIN CONTENT AREA ************** -->
# <footer class="uu-footer" role="contentinfo">
# <div class="uu-container">
# <div class="uu-footer-content">
# <div class="uu-footer-1">
# <p>
#                             Office of the Registrar<br/>
#                             201 S 1460 E RM 250N<br/>
#                             Salt Lake City, UT 84112-9056<br/>
#                             (801) 581-5808<br/>
# </p>
# <p class="elevator-button">Back to the top</p>
# <p><a href="http://www.utah.edu">© The University of Utah</a></p>
# </div>
# <div class="uu-footer-2">
# <ul>
# <li><a href="http://www.utah.edu/nondiscrimination/">Nondiscrimination &amp; Accessibility</a></li>
# <li><a href="http://www.utah.edu/disclaimer/">Disclaimer</a></li>
# <li><a href="http://www.utah.edu/privacy/">Privacy</a></li>
# <li><a href="http://www.utah.edu/contact/">Contact</a></li>
# </ul>
# </div>
# <div class="uu-footer-3">
# </div>
# <div class="uu-footer-4">
# <div class="footer-logo">
# <h2>
# <a href="http://imagineu.utah.edu/"><img alt="Imagine U: The University of Utah" src="//templates.utah.edu/apps/v1/_images/template/imagine_u.png"/></a>
# </h2>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.floatThead._.js"></script>
# <script src="/uofu/stu/ClassSchedules/scripts/jquery.floatThead.js"></script>
# <script>
#         //<![CDATA[
#             if($(window).width() >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }
#             $(window).resize(function(){
#                 if($(window).width() >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }else{
#                    $('table.main-table').floatThead('reflow');
#                 }
#                    if(screen.width >= 1024){
#                     var $table = $('table.main-table');
#                     $table.floatThead();
#                 }else {
#                     $('table.main-table').floatThead('reflow');
#                 }
#             });
#
#          // ]]>
#
#         </script>
# <script src="//templates.utah.edu/apps/v1/_js/vendor/bootstrap.min.js"></script>
# <script src="//templates.utah.edu/apps/v1/_js/main.js"></script>
# </table>

# %% [markdown]
# As usual, that's not very readable. Here's the inspector version:
#
# ![Table](table.png)
#
# We see that the rows without content have two properties: they have a class attribute `notes` and the have only one nested `<td>` – in contrast to the rows that contain data. We could use either of these properties to pick the right dataset.

# %%
# These are the columns we care about
header = ["Subject", "Number", "Section", "Type", "Title", "Instructor", "Students" ]

matrix = []

# for every table row
for row in class_table.find_all("tr"):
    # extracting the tds
    tds = row.find_all("td")
   
    # The columsn in the table are 
    # Class; Subject; Cat. #; Sec.; Component; Units; Title; Days/Time & Session; 
    # Location; Class Attrs; Instructor; Feed back; Pre Req; Fees
    # we want the data defined in the header
    # if there is only a single td, we skip the row because it's one of the "notes" rows.
    if (len(tds) > 3):
        #print(tds[10])
        record = []
        # here we manually extract the field we want. Ugly. But it works. 
        record.append(tds[1].text.strip()) # subject
        record.append(tds[2].text.strip()) # cat #
        record.append(tds[3].text.strip()) # Section
        record.append(tds[4].text.strip()) # Component/Type
        record.append(tds[6].text.strip()) # Title
        record.append(tds[10].text.strip()) # Instructor
        # reconstruct the URL:
        student_url = url+tds[2].find("a").get("href")
        # here we call scrape_students, which extracts the number of students  
        students = scrape_students(student_url)
        record.append(students)
        # print(record)
        matrix.append(record)

# %% [markdown]
# Let's look at the first elements in the matrix:

# %%
matrix[0:4]
# Out:
# [['CS',
#   '1001',
#   '001',
#   'Lecture',
#   'Eng Computing MATLAB',
#   'DE ST GERMAIN, J. D.',
#   16],
#  ['CS',
#   '1001',
#   '002',
#   'Laboratory',
#   'Eng Computing MATLAB',
#   'DE ST GERMAIN, J. D.',
#   16],
#  ['CS', '1030', '001', 'Lecture', 'Foundations of CS', 'JENSEN, P. A.', 130],
#  ['CS',
#   '1030',
#   '002',
#   'Laboratory',
#   'Foundations of CS',
#   'JENSEN, P. A.',
#   130]]

# %% [markdown]
# That looks good! Let's put this into a dataframe:

# %%
classes = pd.DataFrame(matrix, columns=header)
classes.head()
# Out:
#   Subject Number Section        Type                 Title  \
# 0      CS   1001     001     Lecture  Eng Computing MATLAB
# 1      CS   1001     002  Laboratory  Eng Computing MATLAB
# 2      CS   1030     001     Lecture     Foundations of CS
# 3      CS   1030     002  Laboratory     Foundations of CS
# 4      CS   1030     003  Laboratory     Foundations of CS
#
#              Instructor  Students
# 0  DE ST GERMAIN, J. D.        16
# 1  DE ST GERMAIN, J. D.        16
# 2         JENSEN, P. A.       130
# 3         JENSEN, P. A.       130
# 4         JENSEN, P. A.       130

# %% [markdown]
# Back to the cleanup we did earlier:

# %%
classes = classes[(classes["Type"] == "Lecture") | (classes["Type"] == "Seminar") | (classes["Type"] == "Special Topics")]
classes.head()
# Out:
#    Subject Number Section     Type                    Title  \
# 0       CS   1001     001  Lecture     Eng Computing MATLAB
# 2       CS   1030     001  Lecture        Foundations of CS
# 9       CS   1410     001  Lecture     Object-Oriented Prog
# 19      CS   2100     001  Lecture      Discrete Structures
# 25      CS   2420     001  Lecture  Intro Alg & Data Struct
#
#               Instructor  Students
# 0   DE ST GERMAIN, J. D.        16
# 2          JENSEN, P. A.       130
# 9         JOHNSON, D. E.       262
# 19             COHEN, E.       190
# 25            PARKER, D.       300

# %% [markdown]
# When we have sections, students are usually enrolled in the main lecutre “001” in addition to being enrolled in sections (“002”, “003”, etc.) Let's count only the primary sections. This isn't valid for all situations, but fixing that problem autmomatically is hard.

# %%
mask = classes["Section"] == "001"
classes = classes[mask]
classes.head()
# Out:
#    Subject Number Section     Type                    Title  \
# 0       CS   1001     001  Lecture     Eng Computing MATLAB
# 2       CS   1030     001  Lecture        Foundations of CS
# 9       CS   1410     001  Lecture     Object-Oriented Prog
# 19      CS   2100     001  Lecture      Discrete Structures
# 25      CS   2420     001  Lecture  Intro Alg & Data Struct
#
#               Instructor  Students
# 0   DE ST GERMAIN, J. D.        16
# 2          JENSEN, P. A.       130
# 9         JOHNSON, D. E.       262
# 19             COHEN, E.       190
# 25            PARKER, D.       300

# %% [markdown]
# Now let's look at which are the largest classes:

# %%
classes = classes.sort_values("Students", ascending=False)
classes = classes.reset_index(drop=True)
classes.head()
# Out:
#   Subject Number Section     Type                    Title      Instructor  \
# 0      CS   2420     001  Lecture  Intro Alg & Data Struct      PARKER, D.
# 1      CS   1410     001  Lecture     Object-Oriented Prog  JOHNSON, D. E.
# 2      CS   3500     001  Lecture        Software Practice  ZACHARY, J. L.
# 3      CS   2100     001  Lecture      Discrete Structures       COHEN, E.
# 4      CS   3505     001  Lecture     Software Practice II   JENSEN, P. A.
#
#    Students
# 0       300
# 1       262
# 2       192
# 3       190
# 4       174

# %% [markdown]
# Now, we want to answer the question **at which level are the most students enrolled in CS?** Levels are the leading digit of the course number. Let's create a new column level and add it to the dataframe:

# %%
classes["level"] = classes["Number"].map(lambda x: (str(x)[0]))
classes = classes.sort_values(by="level")
classes.head(100)
# Out:
#    Subject Number Section            Type                          Title  \
# 1       CS   1410     001         Lecture           Object-Oriented Prog
# 35      CS   1001     001         Lecture           Eng Computing MATLAB
# 8       CS   1030     001         Lecture              Foundations of CS
# 0       CS   2420     001         Lecture        Intro Alg & Data Struct
# 3       CS   2100     001         Lecture            Discrete Structures
# 43      CS   3992     001         Seminar         Pre-Thesis/Clinic/Proj
# 39      CS   3700     001         Lecture          Digital System Design
# 13      CS   3200     001         Lecture                 Intro Sci Comp
# 9       CS   3130     001         Lecture                 Eng Prob Stats
# 18      CS   3011     001         Lecture                 Industry Forum
# 2       CS   3500     001         Lecture              Software Practice
# 6       CS   3810     001         Lecture          Computer Organization
# 4       CS   3505     001         Lecture           Software Practice II
# 10      CS   4480     001         Lecture              Computer Networks
# 41      CS   4530     001         Lecture         Mobile App Programming
# 31      CS   4470     001         Lecture                      Compilers
# 7       CS   4150     001         Lecture                     Algorithms
# 19      CS   4440     001         Lecture              Computer Security
# 23      CS   4000     001         Lecture         Senior Capstone Design
# 11      CS   4400     001         Lecture               Computer Systems
# 16      CS   4500     001         Lecture        Senior Capstone Project
# 14      CS   4300     001         Lecture        Artificial Intelligence
# 37      CS   5789     001         Lecture          Emb Sys & Kinetic Art
# 20      CS   5140     001         Lecture                    Data Mining
# 59      CS   5740     001         Lecture        CAD of Digital Circuits
# 40      CS   5780     001         Lecture            Embedded Sys Design
# 25      CS   5350     001         Lecture               Machine Learning
# 12      CS   5460     001         Lecture              Operating Systems
# 48      CS   5610     001         Lecture         Interactive Comp Graph
# 5       CS   5530     001         Lecture               Database Systems
# ..     ...    ...     ...             ...                            ...
# 52      CS   6330     001         Lecture         Intro to Robot Control
# 50      CS   6100     001         Lecture          Theory of Computation
# 47      CS   6660     001         Lecture        Physics-based Animation
# 32      CS   6235     001         Lecture        Parallel Prog Many-Core
# 36      CS   6960     001  Special Topics         Fund. of Cloud Systems
# 15      CS   6140     001         Lecture                    Data Mining
# 17      CS   6460     001         Lecture              Operating Systems
# 21      CS   6300     001         Lecture        Artificial Intelligence
# 22      CS   6635     001         Lecture        Vis for Scientific Data
# 38      CS   6360     001         Lecture                Virtual Reality
# 26      CS   6170     001         Lecture         Computational Topology
# 27      CS   6320     001         Lecture                Computer Vision
# 24      CS   6150     001         Lecture            Advanced Algorithms
# 34      CS   6610     001         Lecture         Interactive Comp Graph
# 33      CS   6963     001  Special Topics         Functional Programming
# 30      CS   6350     001         Lecture               Machine Learning
# 63      CS   6740     001         Lecture        CAD of Digital Circuits
# 28      CS   6956     001  Special Topics          Deep Learning for NLP
# 46      CS   7941     001         Seminar           Data Science Seminar
# 61      CS   7930     001         Seminar                 SoC Colloquium
# 58      CS   7937     001         Seminar                      Arch/VLSI
# 57      CS   7939     001         Seminar                       Robotics
# 56      CS   7936     001         Seminar               Security Seminar
# 54      CS   7933     001         Seminar               Graphics Seminar
# 53      CS   7944     001         Seminar         Comp Narrative Seminar
# 44      CS   7935     001         Seminar  Natural Lang. Processing Sem.
# 45      CS   7931     001         Seminar        Computer Vision Seminar
# 49      CS   7942     001         Seminar          Visualization Seminar
# 55      CS   7934     001         Seminar       Computer Systems Seminar
# 64      CS   7943     001         Seminar             Networking Seminar
#
#                                  Instructor  Students level
# 1                            JOHNSON, D. E.       262     1
# 35                     DE ST GERMAIN, J. D.        16     1
# 8                             JENSEN, P. A.       130     1
# 0                                PARKER, D.       300     2
# 3                                 COHEN, E.       190     2
# 43                          BRUNVAND, E. L.        11     3
# 39                             MYERS, C. J.        13     3
# 13                              SHANKAR, V.        95     3
# 9                             COTTER, N. E.       129     3
# 18                     VAN DER MERWE, J. E.        57     3
# 2                            ZACHARY, J. L.       192     3
# 6                         NAZM BOJNORDI, M.       168     3
# 4                             JENSEN, P. A.       174     3
# 10                            KASERA, S. K.       121     4
# 41                            STOKER, M. L.        12     4
# 31                               PARKER, D.        19     4
# 7                            ZACHARY, J. L.       163     4
# 19                              DENNING, T.        50     4
# 23  DE ST GERMAIN, H. J.\n\n\nZIEMEK, T. R.        34     4
# 11                             KOPTA, D. M.       116     4
# 16                     DE ST GERMAIN, H. J.        67     4
# 14                              HERMANS, T.        85     4
# 37         BRUNVAND, E. L.\n\n\nWISCHER, W.        14     5
# 20                             PHILLIPS, J.        41     5
# 59                                KALLA, P.         1     5
# 40                        GAILLARDON, P. J.        12     5
# 25                                  ZHE, S.        27     5
# 12                             STUTSMAN, R.       102     5
# 48                               YUKSEL, C.         8     5
# 5                              KOPTA, D. M.       169     5
# ..                                      ...       ...   ...
# 52                           MASCARO, S. A.         3     6
# 50                       GOPALAKRISHNAN, G.         6     6
# 47                                KAVAN, L.         8     6
# 32                              HALL, M. W.        18     6
# 36                                   JI, M.        14     6
# 15                             PHILLIPS, J.        78     6
# 17                             STUTSMAN, R.        66     6
# 21                        HOLLERBACH, J. M.        36     6
# 22                           JOHNSON, C. R.        34     6
# 38                       CARDONA-RIVERA, R.        13     6
# 26                          PHILLIPS, B. W.        24     6
# 27                           RAMALINGAM, S.        21     6
# 24                   VENKATASUBRAMANIAN, S.        30     6
# 34                               YUKSEL, C.        17     6
# 33                                FLATT, M.        18     6
# 30                                  ZHE, S.        19     6
# 63                                KALLA, P.         0     6
# 28                             SRIKUMAR, V.        20     6
# 46                             PHILLIPS, J.         8     7
# 61                          WHITAKER, R. T.         0     7
# 58                        NAZM BOJNORDI, M.         1     7
# 57                        HOLLERBACH, J. M.         2     7
# 56                              DENNING, T.         2     7
# 54                                KAVAN, L.         2     7
# 53     CARDONA-RIVERA, R.\n\n\nYOUNG, R. M.         3     7
# 44          RILOFF, E. M.\n\n\nSRIKUMAR, V.        10     7
# 45                           RAMALINGAM, S.         9     7
# 49                             PASCUCCI, V.         6     7
# 55                              EIDE, E. N.         2     7
# 64                     VAN DER MERWE, J. E.         0     7
#
# [65 rows x 8 columns]

# %% [markdown]
# We can calculate the answer with groupby:

# %%
import numpy as np
student_stats = classes.groupby("level").aggregate(["count", np.sum, np.mean, np.std])
student_stats
# Out:
#       Students
#          count  sum        mean         std
# level
# 1            3  408  136.000000  123.109707
# 2            2  490  245.000000   77.781746
# 3            8  839  104.875000   72.287991
# 4            9  667   74.111111   51.367413
# 5           11  404   36.727273   52.368103
# 6           20  430   21.500000   20.200313
# 7           12   45    3.750000    3.545163

# %% [markdown]
# Let's visualize this with box plots:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
props = dict(linewidth=2)
# here we group by level
classes.boxplot(by='level', figsize=(10, 10),  boxprops=props, medianprops=props, whiskerprops=props, capprops=props)

# %% [markdown]
# An alternative way with separate figures:

# %%
classes.groupby("level").boxplot(figsize=(13, 13), boxprops=props, medianprops=props, whiskerprops=props, capprops=props)
# Out:
# 1         AxesSubplot(0.1,0.679412;0.235294x0.220588)
# 2    AxesSubplot(0.382353,0.679412;0.235294x0.220588)
# 3    AxesSubplot(0.664706,0.679412;0.235294x0.220588)
# 4         AxesSubplot(0.1,0.414706;0.235294x0.220588)
# 5    AxesSubplot(0.382353,0.414706;0.235294x0.220588)
# 6    AxesSubplot(0.664706,0.414706;0.235294x0.220588)
# 7             AxesSubplot(0.1,0.15;0.235294x0.220588)
# dtype: object

# %% [markdown]
# And plot a bar chart for the number of students in the class:

# %%
student_sum = classes.groupby("level").aggregate([np.sum])
student_sum.plot.bar(legend=False, figsize=(14, 8))

# %% [markdown]
# We can see that the most students are in the 3000 level and there is another peak at the 6000 level classes.

# %% [markdown]
# ## Scraping Wrap-Up
#
# Scraping is a way to get information from website that were not designed to make data accessible. As such, it can often be **brittle**: a website change will break your scraping script. It is also often not welcome, as a scaper can cause a lot of traffic.
#
# The way we scraped information here also made the **assumption that HTML is generated consistently** based just on the URL. That is, unfortunately, less and less common, as websites adapt to browser types, resolutions, locales, but also as a lot of content is loaded dynamically e.g., via web-sockets. For example, many websites now auotmatically load more data once you scroll to the bottom of the page. These websites couldn't be scraped with our approach, instead, a browser-emulation approach, using e.g., [Selenium]() would be necessary. [Here is a tutorial](https://medium.com/the-andela-way/introduction-to-web-scraping-using-selenium-7ec377a8cf72) on how to do that.
#
# Finally, many services make their data available through a well-defined interface, an API. Using an API is always a better idea than scraping, but scraping is a good fallback!

# %% [markdown]
# ## Exercise 1: Exceptional Olympians
#
# Scrape data from [this wikipedia site](https://en.wikipedia.org/wiki/List_of_multiple_Olympic_medalists) about exceptional Olympic medalists.
#
# 1. Download the html using urllib.
# 2. Parse this html with BeautifulSoup.
# 3. Extract the html that corresponds to the big table from the soup.
# 4. Parse the table into a pandas dataframe. Hint: both the "No." and the "Total." column use row-spans which are tricky to parse, both with a pandas reader and manually. For the purpose of this exercise, exclude all rows that are not easy to parse (the first one is Bjørn Dæhlie).
# 5. Create a table that shows for each country how many gold, silver, bronze, and total medals it won in that list.
